# %%
# !git show-ref | grep 'refs/remotes/origin/HEAD'
# Out:
# fatal: git show-ref: bad ref refs/remotes/origin/HEAD 2 (0000000000000000000000000000000000000000)
# 0658b6a1e3c53898e6282d6a80764e0813f27b1a refs/remotes/origin/HEAD
