# %% [markdown]
# # LLM Load Experiment

# %% [markdown]
# ## Library Package Prepare

# %%
# ! export OPENAI_API_KEY="XXX"

# %%
! pip install openai==0.28

# %%
! pip show openai

# %% [markdown]
# - CLIP 跨模态编码器，下面会用到

# %%
! pip install git+https://github.com/openai/CLIP.git

# %%
import clip
print(clip.__file__)

# %% [markdown]
# - 检查当前API接口下，可允许对接什么模型

# %%
import openai

# 设置API密钥
# openai.api_key = "xxx"

# 列出所有可用的模型
models = openai.Model.list()

# 打印所有模型的名称
for model in models['data']:
    print(model['id'])

# %%
import subprocess

def describe_image_with_minigpt4(image_path):
    """
    使用 MiniGPT-4 对图像进行描述（通过 subprocess 调用命令行 evaluate.py）
    """
    prompt = "Describe this image in detail."
    command = [
        "python", "evaluate.py",
        "--cfg-path", "eval_configs/minigpt4_eval.yaml",
        "--gpu-id", "0",
        "--image-path", image_path,
        "--text-input", prompt
    ]
    result = subprocess.run(command, capture_output=True, text=True)
    output = result.stdout.strip()
    
    # 提取最后一句为描述（可根据实际 output 格式调整）
    lines = output.split('\n')
    description = lines[-1] if lines else ""
    return description

# %% [markdown]
# ## MiniGPT-4

# %% [markdown]
# ## MiniGPT-4

# %%
! conda init
! conda activate minigpt4

# %%
# ! git clone https://github.com/Vision-CAIR/MiniGPT-4.git
# # ! git clone https://github.com/Vision-CAIR/MiniGPT-4.git

# ! cd MiniGPT-4

# %% [markdown]
# - 下载新的编译环境

# %%
! curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh

# %%
! rustc --version
# Out:
# zsh:1: command not found: rustc

# %%
! pip install transformers

# %%
! pip install tokenizers

# %%
# ! git clone https://github.com/Vision-CAIR/MiniGPT-4.git
# ! cd MiniGPT-4

# 安装基础依赖
# ! pip install -r requirements.txt

# 安装必要库
! pip install accelerate==0.18.0 bitsandbytes==0.37.0
# Out:
# Collecting accelerate==0.18.0
#   Using cached accelerate-0.18.0-py3-none-any.whl.metadata (16 kB)
# Collecting bitsandbytes==0.37.0
#   Using cached bitsandbytes-0.37.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from accelerate==0.18.0) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from accelerate==0.18.0) (25.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from accelerate==0.18.0) (7.0.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from accelerate==0.18.0) (6.0.2)
# Requirement already satisfied: torch>=1.4.0 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from accelerate==0.18.0) (2.8.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from torch>=1.4.0->accelerate==0.18.0) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from torch>=1.4.0->accelerate==0.18.0) (4.15.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from torch>=1.4.0->accelerate==0.18.0) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from torch>=1.4.0->accelerate==0.18.0) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from torch>=1.4.0->accelerate==0.18.0) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from torch>=1.4.0->accelerate==0.18.0) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from torch>=1.4.0->accelerate==0.18.0) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.4.0->accelerate==0.18.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from jinja2->torch>=1.4.0->accelerate==0.18.0) (3.0.2)
# Using cached accelerate-0.18.0-py3-none-any.whl (215 kB)
# Using cached bitsandbytes-0.37.0-py3-none-any.whl (76.3 MB)
# Installing collected packages: bitsandbytes, accelerate
#   Attempting uninstall: accelerate━━━━━━━━━━━━━━ 0/2 [bitsandbytes]
#     Found existing installation: accelerate 1.4.00/2 [bitsandbytes]
#     Uninstalling accelerate-1.4.0:━━━━━━━━━━ 0/2 [bitsandbytes]
#       Successfully uninstalled accelerate-1.4.0m 0/2 [bitsandbytes]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [accelerate]2 [accelerate]
# Successfully installed accelerate-0.18.0 bitsandbytes-0.37.0

# %%
! pip install flash-attn --no-build-isolation
# Out:
# Collecting flash-attn
#   Downloading flash_attn-2.8.3.tar.gz (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 7.6 MB/s  0:00:01 eta 0:00:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [39 lines of output]
#
#
#       torch.__version__  = 2.8.0
#
#
#       /private/var/folders/nk/1w4w_4vj1q56j6rffdl50r_80000gn/T/pip-install-n3e2y9e3/flash-attn_79a0cd7e0dfa459c8ca25375f120bedc/setup.py:106: UserWarning: flash_attn was requested, but nvcc was not found.  Are you sure your environment has nvcc available?  If you're installing within a container from https://hub.docker.com/r/pytorch/pytorch, only images whose names contain 'devel' will provide nvcc.
#         warnings.warn(
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#           exec(compile('''
#           ~~~~^^^^^^^^^^^^
#           # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ...<32 lines>...
#           exec(compile(setup_py_code, filename, "exec"))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ''' % ('/private/var/folders/nk/1w4w_4vj1q56j6rffdl50r_80000gn/T/pip-install-n3e2y9e3/flash-attn_79a0cd7e0dfa459c8ca25375f120bedc/setup.py',), "<pip-setuptools-caller>", "exec"))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/private/var/folders/nk/1w4w_4vj1q56j6rffdl50r_80000gn/T/pip-install-n3e2y9e3/flash-attn_79a0cd7e0dfa459c8ca25375f120bedc/setup.py", line 227, in <module>
#           CUDAExtension(
#           ~~~~~~~~~~~~~^
#               name="flash_attn_2_cuda",
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#           ...<83 lines>...
#               ],
#               ^^
#           )
#           ^
#         File "/opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/utils/cpp_extension.py", line 1337, in CUDAExtension
#           library_dirs += library_paths(device_type="cuda")
#                           ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#         File "/opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/utils/cpp_extension.py", line 1548, in library_paths
#           if (not os.path.exists(_join_cuda_home(lib_dir)) and
#                                  ~~~~~~~~~~~~~~~^^^^^^^^^
#         File "/opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/utils/cpp_extension.py", line 2982, in _join_cuda_home
#           raise OSError('CUDA_HOME environment variable is not set. '
#                         'Please set it to your CUDA install root.')
#       OSError: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
! pip install omegaconf gradio einops

# %%
! pip install iopath
# Out:
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from iopath) (4.67.1)
# Requirement already satisfied: typing_extensions in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from iopath) (4.15.0)
# Collecting portalocker (from iopath)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: iopath
#   DEPRECATION: Building 'iopath' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'iopath'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31529 sha256=38081b6f6dc8af54320b531fbdee7b356cb9c300a742716ab3d6c46af7b33439
#   Stored in directory: /Users/suleynan_suir/Library/Caches/pip/wheels/cd/c4/19/776124f304c8d9cb940cb164ec2ad635b42d9d1cf03217506d
# Successfully built iopath
# Installing collected packages: portalocker, iopath
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [iopath]
# Successfully installed iopath-0.1.10 portalocker-3.2.0

# %%
! pip install iopath omegaconf gradio einops bitsandbytes

# %%
# 命令行登录 Hugging Face（推荐）
! huggingface-cli login

# %%
! pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 7.4 MB/s  0:00:05m0:00:0100:01
# Downloading numpy-2.2.6-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 7.3 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: numpy, opencv-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.1
#     Uninstalling numpy-2.3.1:
#       Successfully uninstalled numpy-2.3.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opencv-python]0m [opencv-python]
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88

# %%
! pip install visual-genome
# Out:
# Collecting visual-genome
#   Downloading visual_genome-1.1.1-py2.py3-none-any.whl.metadata (840 bytes)
# Collecting progressbar2 (from visual-genome)
#   Downloading progressbar2-4.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from visual-genome) (2.32.5)
# Collecting python-utils>=3.8.1 (from progressbar2->visual-genome)
#   Downloading python_utils-3.9.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: typing_extensions>3.10.0.2 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from python-utils>=3.8.1->progressbar2->visual-genome) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from requests->visual-genome) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from requests->visual-genome) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from requests->visual-genome) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from requests->visual-genome) (2025.8.3)
# Downloading visual_genome-1.1.1-py2.py3-none-any.whl (9.6 kB)
# Downloading progressbar2-4.5.0-py3-none-any.whl (57 kB)
# Downloading python_utils-3.9.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: python-utils, progressbar2, visual-genome
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [visual-genome]
# Successfully installed progressbar2-4.5.0 python-utils-3.9.1 visual-genome-1.1.1

# %%
! pip install peft

# %%
# 进入模型权重目录
! mkdir -p checkpoints/minigpt4
! cd checkpoints/minigpt4

# 你需要从 Hugging Face 或项目作者提供的 Google Drive 链接中获取：
# - pretrained_minigpt4.pth
# - config.yaml

# %%
import os

# 替换为 MiniGPT-4 项目的真实路径
# /Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/experiment_LLM/MiniGPT-4
project_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/experiment_LLM/MiniGPT-4"

os.chdir(project_path)
print("当前工作目录已切换到：", os.getcwd())
# Out:
# 当前工作目录已切换到： /Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/experiment_LLM/MiniGPT-4

# %%
import subprocess

cfg_path = "eval_configs/minigpt4_eval.yaml"
gpu_id = "0"
image_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/img/01327.png"
text_input = "Describe this image in detail."

command = [
    "python", "evaluate.py",
    "--cfg-path", cfg_path,
    "--gpu-id", gpu_id,
    "--image-path", image_path,
    "--text-input", text_input
]

result = subprocess.run(command, capture_output=True, text=True)

print("MiniGPT-4 输出：")
print(result.stdout)

if result.stderr:
    print("❌ 错误信息：")
    print(result.stderr)
# Out:
# MiniGPT-4 输出：
#
# ❌ 错误信息：
# /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/timm/models/hub.py:4: FutureWarning: Importing from timm.models.hub is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Traceback (most recent call last):
#   File "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/experiment_LLM/MiniGPT-4/evaluate.py", line 6, in <module>
#     from minigpt4.models import load_pretrained_model
#   File "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/experiment_LLM/MiniGPT-4/minigpt4/__init__.py", line 16, in <module>
#     from minigpt4.models import *
#   File "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/experiment_LLM/MiniGPT-4/minigpt4/models/__init__.py", line 15, in <module>
#     from minigpt4.models.minigpt4 import MiniGPT4
#   File "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/experiment_LLM/MiniGPT-4/minigpt4/models/minigpt4.py", line 11, in <module>
#     from minigpt4.models.Qformer import BertConfig, BertLMHeadModel
#   File "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/experiment_LLM/MiniGPT-4/minigpt4/models/Qformer.py", line 39, in <module>
#     from transformers.modeling_utils import (
#     ...<4 lines>...
#     )
# ImportError: cannot import name 'apply_chunking_to_forward' from 'transformers.modeling_utils' (/opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/transformers/modeling_utils.py)

# %% [markdown]
# ---

# %% [markdown]
# ## BLIP-based Experiment (non-finished)

# %%
from PIL import Image
import requests
from io import BytesIO

# 加载图片
def load_image(image_path):
    image = Image.open(image_path)  # 从文件路径加载图片
    return image

# 如果您使用的是URL上传图片，则需要进行图像URL的请求：
def load_image_from_url(image_url):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    return image

# %%
! pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from pytesseract) (11.3.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %% [markdown]
# ### BLIP-based Level-1

# %%
import openai
import requests
from PIL import Image
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration
import pytesseract  # 用于OCR（文字识别）

# 设置API密钥和URL
API_SECRET_KEY = "sk-zk21884c49fc398427914f99fc30171ecb068f998dc6f05b"
BASE_URL = "https://api.zhizengzeng.com/v1/chat/completions"

# 加载BLIP模型和处理器
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 加载图像并进行处理
def load_image(image_path, resize=True):
    image = Image.open(image_path)
    if resize:
        image = image.resize((512, 512))  # 调整图像大小以加速处理
    return image

# 图像文字识别函数（OCR）
def extract_text_from_image(image_path):
    image = load_image(image_path)
    text = pytesseract.image_to_string(image)  # 使用tesseract进行OCR
    return text.strip()  # 返回图像中的文字内容

# 使用BLIP生成图像描述
def describe_image_with_blip(image_path):
    image = load_image(image_path)
    
    # 图像处理
    inputs = processor(image, return_tensors="pt")
    
    # 生成图像描述
    out = model.generate(**inputs)
    description = processor.decode(out[0], skip_special_tokens=True)
    return description

# 生成分析内容的Prompt
def generate_analysis_prompt(image_path, description):
    # 提取图像中的文本
    text_from_image = extract_text_from_image(image_path)
    
    # 构造用于生成分析的Prompt，结合图像描述与图像中的文字
    prompt = (
        f"请分析以下图像内容，结合图像中的文字：\n"
        f"图像描述：{description}\n"
        f"图像中的文字：{text_from_image}\n"
        f"请简洁描述图像中的不良内容，涉及歧视、暴力、血腥、误导性等。"
    )
    return prompt

# 进一步分析描述
def analyze_caption_with_gpt4(description, image_path):
    prompt = generate_analysis_prompt(image_path, description)
    
    analysis_url = "https://api.zhizengzeng.com/v1/chat/completions"
    
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {API_SECRET_KEY}',
    }
    
    data = {
        "model": "gpt-4.1",
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ]
    }
    
    response = requests.post(analysis_url, headers=headers, json=data)
    
    if response.status_code == 200:
        result = response.json()
        analysis = result["choices"][0]["message"]["content"]
        return analysis
    else:
        return f"Error: {response.status_code}, {response.text}"

# 主函数示例：上传图像并分析描述
def main(image_path):
    # 使用BLIP生成图像描述
    description = describe_image_with_blip(image_path)
    print("生成的描述：", description)

    # 分析图像描述
    analysis = analyze_caption_with_gpt4(description, image_path)
    print("分析结果：", analysis)

# 示例图片路径，替换为您的图片路径
image_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/img/01327.png"  # 替换为您的图片路径
main(image_path)
# Out:
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 12520.31it/s]
# 生成的描述： a picture of a joker with a caption
# 分析结果： 该图像展示了一位小丑（Joker），配以文字“Im not sick, i'm DISSE of Be Sick makes it oui like there's acure”。其内容存在如下不良要素：
#
# - **歧视与误导性**：文字部分表达了“不是真的生病，而是……（DISSE）”，并暗示“生病是可以治愈的”，可能在语义上模糊甚至贬损心理健康障碍等真实疾病，存在心理疾病污名化及误导性说法的风险。
# - **Joker形象**：该形象常与暴力、混乱等负面文化符号相关，整体氛围可能引发不适或误导性联想。
#
# 总体而言，图像存在对疾病（特别是心理疾病）的误导性描述，可能含有歧视成分，并利用小丑（Joker）形象营造潜在的不良社会影响。

# %% [markdown]
# ### BLIP-based Level-2

# %%
import openai
import requests
import time
from PIL import Image
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration
import pytesseract  # 用于OCR（文字识别）

# 设置API密钥和URL
API_SECRET_KEY = "sk-zk21884c49fc398427914f99fc30171ecb068f998dc6f05b"
BASE_URL = "https://api.zhizengzeng.com/v1/chat/completions"

# 加载BLIP模型和处理器
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 加载图像并进行处理
def load_image(image_path, resize=False):
    image = Image.open(image_path)
    if resize:
        image = image.resize((512, 512))  # 调整图像大小以加速处理
    return image

# 图像文字识别函数（OCR）
def extract_text_from_image(image_path):
    image = load_image(image_path)
    text = pytesseract.image_to_string(image)  # 使用tesseract进行OCR
    return text.strip()  # 返回图像中的文字内容

# 使用BLIP生成图像描述
def describe_image_with_blip(image_path):
    image = load_image(image_path)
    
    # 图像处理
    inputs = processor(image, return_tensors="pt")
    
    # 生成图像描述
    out = model.generate(**inputs)
    description = processor.decode(out[0], skip_special_tokens=True)
    return description

# 生成分析内容的Prompt
def generate_analysis_prompt(image_path, description):
    # 提取图像中的文本
    text_from_image = extract_text_from_image(image_path)
    
    # 构造用于生成分析的Prompt，结合图像描述与图像中的文字
    prompt = (
        f"请分析以下图像内容，结合图像中的文字：\n"
        f"图像描述：{description}\n"
        f"图像中的文字：{text_from_image}\n"
        f"请详细分析图像中可能包含的不良要素，涉及：\n"
        f"1. 歧视性言论或行为\n"
        f"2. 暴力或血腥元素\n"
        f"3. 误导性信息或虚假内容\n"
        f"4. 种族、民族、性别或文化背景的歧视\n"
        f"5. 其他可能的不良或有害内容\n"
        f"分析应结合图片中的背景和上下文，指出潜在的恶意信息和不当语言的深层含义。"
    )
    return prompt

# 进一步分析描述
def analyze_caption_with_gpt4(description, image_path):
    prompt = generate_analysis_prompt(image_path, description)

    analysis_url = "https://api.zhizengzeng.com/v1/chat/completions"
    
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {API_SECRET_KEY}',
    }
    
    data = {
        "model": "gpt-4.1",
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ]
    }

    # 开始计时
    start_time = time.time()

    # 发起请求
    response = requests.post(analysis_url, headers=headers, json=data)

    # 结束计时
    end_time = time.time()

    # 计算推理时间
    inference_time = end_time - start_time

    # 计算token数和费用
    tokens_used = response.json().get('usage', {}).get('total_tokens', 0)
    cost = (tokens_used / 1000) * 0.03  # 假设费用为每1000个token 0.03美元

    # 输出推理时间、token和费用
    print(f"推理时间: {inference_time:.2f}秒")
    print(f"消耗Token数量: {tokens_used}")
    print(f"推理费用: ${cost:.4f}")

    if response.status_code == 200:
        result = response.json()
        analysis = result["choices"][0]["message"]["content"]
        return analysis
    else:
        return f"Error: {response.status_code}, {response.text}"

# 主函数示例：上传图像并分析描述
def main(image_path):
    # 使用BLIP生成图像描述
    description = describe_image_with_blip(image_path)
    print("生成的描述：", description)

    # 分析图像描述
    analysis = analyze_caption_with_gpt4(description, image_path)
    print("分析结果：", analysis)

# 示例图片路径，替换为您的图片路径
image_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/img/01327.png"  # 替换为您的图片路径
main(image_path)
# Out:
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 798.92it/s]
# 生成的描述： a picture of a joker with a caption
# 推理时间: 10.64秒
# 消耗Token数量: 1024
# 推理费用: $0.0307
# 分析结果： 根据你提供的图像描述与文字内容，下面进行详细分析：
#
# ---
#
# ### 1. 歧视性言论或行为
#
# 文字内容：“im not sick...sick makes it 'sound like there's a cure'”
#
# **分析：**
# 此语句表达了一种对于“病/疾病”标签的否定，暗示被称为“有病”不是应被治疗的状态，而或许是某种不可治愈、甚至为永久、被社会排斥的状况。结合小丑形象，这句话容易被理解为对心理疾病（如精神疾病、反社会人格障碍等）的污名化，或者美化极端、异常的行为，强化了社会对心理问题的负面认知，对真正有精神健康问题的人群造成了伤害和歧视。
#
# ---
#
# ### 2. 暴力或血腥元素
#
# **分析：**
# 虽然文字本身没有直接描述暴力，但小丑（joker）形象通常与极端暴力、混乱、犯罪行为等相关联，尤其在流行文化中（如电影《Joker》）。配合上述文字，容易让人联想到崇拜、合理化甚至美化暴力或反社会行为。若图片中小丑面部有扭曲、恐怖或带有武器等表现，则增加对暴力行为的暗示。
#
# ---
#
# ### 3. 误导性信息或虚假内容
#
# **分析：**
# “sick makes it ‘sound like there’s a cure’”暗示某些心理或精神问题无法被治愈，可能误导公众对心理疾病的认知。当前医学和社会对于心理、精神疾病拥有多种治疗途径，传播‘无法治愈’的信息可能让患者放弃治疗或社会认为不应帮助此类人群。这属于消极误导性信息，不利于公众心理健康观念的建设。
#
# ---
#
# ### 4. 种族、民族、性别或文化背景的歧视
#
# **分析：**
# 目前图像和文字未直接涉及特定种族、民族、性别或文化，但小丑形象在部分文化中本身具有恶意符号，如“边缘化”、“异类”，间接强化了对某类不同社会行为者的排斥。
#
# ---
#
# ### 5. 其他可能的不良或有害内容
#
# - **鼓励自我异化/反社会身份认同**：“im not sick”声明自己的行为非病态，隐含鼓励对社会规范的抵抗，与小丑象征的“混乱”形成呼应，可能诱导青少年模仿或认同极端行为。
# - **消极世界观传播**：整个语句呈现一种孤立、极端，不被理解的态度，可能影响心理敏感人群，引发共鸣甚至负面心理或行为。
#
# ---
#
# ### 综合分析（深层含义）
#
# 该图像和文字传达了对“病态”标签的拒绝和自我认同的复杂信息。配合小丑作为象征，暗示反社会、极端个体的困境，易被解读为对心理疾病污名化、暴力及反社会人格的美化，同时带有误导性和潜在伤害。对于青少年或心理敏感人群，这可能是一个不良心理引导，传播消极、极端的世界观。
#
# **建议：**
# 对大众应避免渲染或美化精神障碍、暴力、反社会行为。传播应关注心理健康科学知识与社会包容。此类内容如以娱乐、艺术为目的需加强信息引导，避免误解和负面影响。
#
# ---
#
# 如需对具体图片（如图片中的小丑表情、姿势、场景）的细节分析，可补充说明，我会结合更多元素详细解析。

# %% [markdown]
# ### BLIP-based Level-2

# %%
import openai
import requests
from PIL import Image
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration
import pytesseract  # 用于OCR（文字识别）

# 设置API密钥和URL
API_SECRET_KEY = "sk-zk21884c49fc398427914f99fc30171ecb068f998dc6f05b"
BASE_URL = "https://api.zhizengzeng.com/v1/chat/completions"

# 加载BLIP模型和处理器
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 扩展的关键词列表
keywords = [
    '暴力', '攻击', '恐怖主义', '战争', '杀戮', '残忍',
    '种族歧视', '性别歧视', '年龄歧视', '贫富差距', '身体歧视', '宗教歧视', 
    '同性恋歧视', '外貌歧视', '血腥', '凶杀', '残忍行为', '血腥场面',
    '谣言', '假新闻', '恶意炒作', '虚假信息', '误导性广告',
    '仇恨', '恶意攻击', '恶性竞争', '污蔑', '恶意散布',
    '不道德', '不正当手段', '欺诈', '贪婪', '非法活动', '敲诈', '诈骗',
    '仇恨言论', '仇恨犯罪', '排外', '性别仇恨', '宗教仇恨',
    '精神虐待', '心理操控', '精神暴力', '霸凌', '讽刺', '贬低',
    '毒品', '吸毒', '暴饮暴食', '酗酒', '赌博',
    '淫秽内容', '色情', '淫秽语言', '性骚扰', '侵犯隐私',
    '贫困', '贫困歧视', '社会不公', '政治迫害', '暴政',
    '极端主义', '极右翼', '极左翼', '民族主义', '恐怖主义意识形态'
]

# 加载图像并进行处理
def load_image(image_path, resize=True):
    image = Image.open(image_path)
    if resize:
        image = image.resize((512, 512))  # 调整图像大小以加速处理
    return image

# 图像文字识别函数（OCR）
def extract_text_from_image(image_path):
    image = load_image(image_path)
    text = pytesseract.image_to_string(image)  # 使用tesseract进行OCR
    return text.strip()  # 返回图像中的文字内容

# 使用BLIP生成图像描述
def describe_image_with_blip(image_path):
    image = load_image(image_path)

    # 图像处理
    inputs = processor(image, return_tensors="pt")

    # 生成图像描述
    out = model.generate(**inputs)
    description = processor.decode(out[0], skip_special_tokens=True)
    return description

# 生成分析内容的Prompt
def generate_analysis_prompt(image_path, description):
    # 提取图像中的文本
    text_from_image = extract_text_from_image(image_path)

    # 构造用于生成分析的Prompt，结合图像描述与图像中的文字
    prompt = (
        f"请分析以下图像内容，结合图像中的文字：\n"
        f"图像描述：{description}\n"
        f"图像中的文字：{text_from_image}\n"
        f"请简洁描述图像中的不良内容，涉及歧视、暴力、血腥、误导性等。"
    )
    return prompt

# 提取关键字的函数
def extract_key_word(analysis):
    for keyword in keywords:
        if keyword in analysis:
            return keyword
    return "无明显关键字"

# 进一步分析描述
def analyze_caption_with_gpt4(description, image_path):
    prompt = generate_analysis_prompt(image_path, description)

    analysis_url = "https://api.zhizengzeng.com/v1/chat/completions"

    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {API_SECRET_KEY}',
    }

    data = {
        "model": "gpt-4.1",
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ]
    }

    response = requests.post(analysis_url, headers=headers, json=data)

    if response.status_code == 200:
        result = response.json()
        analysis = result["choices"][0]["message"]["content"]
        key_word = extract_key_word(analysis)
        hateful_or_not = 1 if "不良" in analysis or "仇恨" in key_word else 0
        return analysis, key_word, hateful_or_not
    else:
        return f"Error: {response.status_code}, {response.text}", None, None

# 主函数示例：上传图像并分析描述
def main(image_path):
    # 使用BLIP生成图像描述
    description = describe_image_with_blip(image_path)
    print("生成的描述：", description)

    # 分析图像描述
    analysis, key_word, hateful_or_not = analyze_caption_with_gpt4(description, image_path)
    print("分析结果：", analysis)
    print("关键字：", key_word)
    print("是否含有不良信息：", "1（有）" if hateful_or_not == 1 else "0（没有）")

# 示例图片路径，替换为您的图片路径
image_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/img/01327.png"  # 替换为您的图片路径
main(image_path)
# Out:
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 21845.33it/s]
# 生成的描述： a picture of a joker with a caption
# 分析结果： 该图像为小丑（joker）形象，配以英文文字“Im not sick, i'm DISSE... Sick makes it oui like there's a cure”。图中文字涉及对心理健康问题的歧视（将“病态”与“邪恶”混为一谈），可能强化对精神疾病患者的负面刻板印象。此外，小丑形象常与暴力及反社会行为相关联，图像有一定误导性，暗示心理疾病等同于无法治愈的危险行为，这可能对易受影响的人群产生不良影响。
# 关键字： 暴力
# 是否含有不良信息： 1（有）

# %% [markdown]
# ### BLIP-based Level-2

# %%
import openai
import os
import requests
from PIL import Image
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration
import pytesseract  # 用于OCR（文字识别）
import time

# 设置API密钥和URL
API_SECRET_KEY = "sk-zk21884c49fc398427914f99fc30171ecb068f998dc6f05b"
BASE_URL = "https://api.zhizengzeng.com/v1/chat/completions"

# 加载BLIP模型和处理器
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 扩展的关键词列表
keywords = [
    '暴力', '攻击', '恐怖主义', '战争', '杀戮', '残忍',
    '种族歧视', '性别歧视', '年龄歧视', '贫富差距', '身体歧视', '宗教歧视', 
    '同性恋歧视', '外貌歧视', '血腥', '凶杀', '残忍行为', '血腥场面',
    '谣言', '假新闻', '恶意炒作', '虚假信息', '误导性广告',
    '仇恨', '恶意攻击', '恶性竞争', '污蔑', '恶意散布',
    '不道德', '不正当手段', '欺诈', '贪婪', '非法活动', '敲诈', '诈骗',
    '仇恨言论', '仇恨犯罪', '排外', '性别仇恨', '宗教仇恨',
    '精神虐待', '心理操控', '精神暴力', '霸凌', '讽刺', '贬低',
    '毒品', '吸毒', '暴饮暴食', '酗酒', '赌博',
    '淫秽内容', '色情', '淫秽语言', '性骚扰', '侵犯隐私',
    '贫困', '贫困歧视', '社会不公', '政治迫害', '暴政',
    '极端主义', '极右翼', '极左翼', '民族主义', '恐怖主义意识形态'
]

# 加载图像并进行处理
def load_image(image_path, resize=True):
    image = Image.open(image_path)
    if resize:
        image = image.resize((512, 512))  # 调整图像大小以加速处理
    return image

# 图像文字识别函数（OCR）
def extract_text_from_image(image_path):
    image = load_image(image_path)
    text = pytesseract.image_to_string(image)  # 使用tesseract进行OCR
    return text.strip()  # 返回图像中的文字内容

# 使用BLIP生成图像描述
def describe_image_with_blip(image_path):
    image = load_image(image_path)
    
    # 图像处理
    inputs = processor(image, return_tensors="pt")
    
    # 生成图像描述
    out = model.generate(**inputs)
    description = processor.decode(out[0], skip_special_tokens=True)
    return description

# 生成分析内容的Prompt
def generate_analysis_prompt(image_path, description):
    # 提取图像中的文本
    text_from_image = extract_text_from_image(image_path)
    
    # 构造用于生成分析的Prompt，结合图像描述与图像中的文字
    prompt = (
        f"请分析以下图像内容，结合图像中的文字：\n"
        f"图像描述：{description}\n"
        f"图像中的文字：{text_from_image}\n"
        f"请简洁描述图像中的不良内容，涉及歧视、暴力、血腥、误导性等。"
    )
    return prompt

# 分析图像描述，返回key word和hateful or not
def analyze_caption_with_gpt4(description, image_path):
    prompt = generate_analysis_prompt(image_path, description)

    analysis_url = "https://api.zhizengzeng.com/v1/chat/completions"
    
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {API_SECRET_KEY}',
    }
    
    data = {
        "model": "gpt-4.1",
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ]
    }

    # 开始计时
    start_time = time.time()

    # 发起请求
    response = requests.post(analysis_url, headers=headers, json=data)

    # 结束计时
    end_time = time.time()

    # 计算推理时间
    inference_time = end_time - start_time

    # 计算token数和费用
    tokens_used = response.json().get('usage', {}).get('total_tokens', 0)
    cost = (tokens_used / 1000) * 0.03  # 假设费用为每1000个token 0.03美元

    # 输出推理时间、token和费用
    print(f"推理时间: {inference_time:.2f}秒")
    print(f"消耗Token数量: {tokens_used}")
    print(f"推理费用: ${cost:.4f}")

    # 分析结果
    if response.status_code == 200:
        result = response.json()
        analysis = result["choices"][0]["message"]["content"]
        
        # 提取关键字和判断是否为不良内容
        key_word = extract_key_word(analysis)
        hateful_or_not = 1 if '歧视' in analysis or '暴力' in analysis or '血腥' in analysis else 0
        
        return analysis, key_word, hateful_or_not
    else:
        return f"Error: {response.status_code}, {response.text}", "", 0

# 提取关键字的简单方法
def extract_key_word(analysis):
    for keyword in keywords:
        if keyword in analysis:
            return keyword
    return "无明显关键字"

# 读取文件夹中的图像并分析
def analyze_images_in_folder(folder_path, num_images=None):
    files = os.listdir(folder_path)
    image_files = [f for f in files if f.endswith(('jpg', 'jpeg', 'png', 'bmp'))]
    
    if num_images:
        image_files = image_files[:num_images]  # 限制读取的图像数量

    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        print(f"正在分析: {image_file}")
        
        # 使用BLIP生成图像描述
        description = describe_image_with_blip(image_path)
        print("生成的描述：", description)

        # 分析图像描述
        analysis, key_word, hateful_or_not = analyze_caption_with_gpt4(description, image_path)
        print("分析结果：", analysis)
        print(f"关键字: {key_word}")
        print(f"hateful or not: {hateful_or_not}\n")

# 主函数示例：上传图像并分析描述
def main():
    # 示例文件夹路径，替换为您的图片文件夹路径
    folder_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/img"  # 替换为您的文件夹路径
    analyze_images_in_folder(folder_path, num_images=3)  # 分析前5张图片

# 执行主函数
main()
# Out:
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 4524.60it/s]
# 正在分析: 69351.png
# 生成的描述： a pig that is smiling
# 推理时间: 6.29秒
# 消耗Token数量: 246
# 推理费用: $0.0074
# 分析结果： 该图像展示了一只微笑的猪，配有文字“heyimusiinmeatine!”。这句话模糊表达为“Hey, I'm using meat in me!”（大意为：嘿，我自己就是肉！）。结合猪的表情和文字，包含以下不良内容：
#
# - 可能误导或讽刺地物化动物为肉制品，带有对动物的不尊重，涉及动物权利议题。
# - 文字表达容易引发对食肉或动物屠宰行为的血腥化联想。
# - 有一定争议性，可能引发针对特定饮食习惯或群体的歧视讨论。
#
# 整体内容具有误导和争议，并可能引起对于动物福利或饮食选择的负面情绪。
# 关键字: 血腥
# hateful or not: 1
#
# 正在分析: 17843.png
# 生成的描述： a man is working on a table in a room
# 推理时间: 6.05秒
# 消耗Token数量: 260
# 推理费用: $0.0078
# 分析结果： 该图像包含不良内容，主要表现如下：
#
# 1. 语言不当：图像中的文字含有脏话（如 "fuckin"），存在粗俗、低俗用语。
# 2. 信息可能误导：文字提及“a little foil on ton keeps themiju icy met mrareis best”，内容晦涩、不明，可能暗示不明用途或误导性行为，但具体意图不明确。
# 3. 未发现明显歧视、暴力或血腥内容：图像与文字未经进一步说明，未直接涉及针对特定群体的歧视言论、暴力或血腥场面。
#
# 总结：该图像的主要不良内容是语言粗俗和可能的误导性表达。
# 关键字: 暴力
# hateful or not: 1
#
# 正在分析: 27980.png
# 生成的描述： a little girl kissing a little girl
# 推理时间: 3.00秒
# 消耗Token数量: 230
# 推理费用: $0.0069
# 分析结果： 根据您的描述，图像内容为：“一名小女孩亲吻另一名小女孩”，图像中的文字为：“when the vegetables”。
#
# 分析如下：
# - 图像画面本身为两个小女孩之间的亲吻行为，没有描述出明显的暴力、血腥或歧视内容。
# - 图像文字“when the vegetables”没有明显的误导性、歧视或不良暗示。如果没有进一步上下文，无法判断其是否与画面构成不良内容。
#
# 简洁结论：
# 该图像在您提供的信息下未直接体现歧视、暴力、血腥、误导性等不良内容。如有更具体背景或语境，请补充说明以便进一步分析。
# 关键字: 暴力
# hateful or not: 1

# %%
! pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting nltk>=3.9 (from textblob)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from nltk>=3.9->textblob) (8.3.0)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from nltk>=3.9->textblob) (4.67.1)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 1.9 MB/s  0:00:0036m-:--:--
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.1 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: nltk, textblob
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [textblob]
# Successfully installed nltk-3.9.2 textblob-0.19.0

# %% [markdown]
# ### BLIP-based Level-3: Better Prompt

# %%
import openai
import os
import requests
from PIL import Image
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration, BertTokenizer, BertForSequenceClassification
import pytesseract  # 用于OCR（文字识别）
from textblob import TextBlob  # 用于情感分析
import time
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# 设置API密钥和URL
API_SECRET_KEY = "sk-zk21884c49fc398427914f99fc30171ecb068f998dc6f05b"
BASE_URL = "https://api.zhizengzeng.com/v1/chat/completions"

# 加载BLIP模型和处理器
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 加载BERT模型（用于语义理解）
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

# 扩展的关键词列表
keywords =  [
    '暴力', '攻击', '恐怖主义', '战争', '杀戮', '残忍',
    '种族歧视', '性别歧视', '年龄歧视', '贫富差距', '身体歧视', '宗教歧视', 
    '同性恋歧视', '外貌歧视', '血腥', '凶杀', '残忍行为', '血腥场面',
    '谣言', '假新闻', '恶意炒作', '虚假信息', '误导性广告',
    '仇恨', '恶意攻击', '恶性竞争', '污蔑', '恶意散布',
    '不道德', '不正当手段', '欺诈', '贪婪', '非法活动', '敲诈', '诈骗',
    '仇恨言论', '仇恨犯罪', '排外', '性别仇恨', '宗教仇恨',
    '精神虐待', '心理操控', '精神暴力', '霸凌', '讽刺', '贬低',
    '毒品', '吸毒', '暴饮暴食', '酗酒', '赌博',
    '淫秽内容', '色情', '淫秽语言', '性骚扰', '侵犯隐私',
    '贫困', '贫困歧视', '社会不公', '政治迫害', '暴政',
    '极端主义', '极右翼', '极左翼', '民族主义', '恐怖主义意识形态'
]

# 加载图像并进行处理
def load_image(image_path, resize=True):
    image = Image.open(image_path)
    if resize:
        image = image.resize((512, 512))  # 调整图像大小以加速处理
    return image

# 图像文字识别函数（OCR）
def extract_text_from_image(image_path):
    image = load_image(image_path)
    text = pytesseract.image_to_string(image)  # 使用tesseract进行OCR
    return text.strip()  # 返回图像中的文字内容

# 使用BLIP生成图像描述
def describe_image_with_blip(image_path):
    image = load_image(image_path)
    inputs = processor(image, return_tensors="pt")
    out = model.generate(**inputs)
    description = processor.decode(out[0], skip_special_tokens=True)
    return description

# 生成分析内容的Prompt
def generate_analysis_prompt(image_path, description):
    text_from_image = extract_text_from_image(image_path)
    prompt = (
        f"假如你是一位具有非常丰富经验的心理学家、社会学家，现在需要完成**Facebook Hateful Memes Detection**任务请你分析以下图像内容，结合图像中的文字：\n"
        f"图像描述：{description}\n"
        f"图像中的文字：{text_from_image}\n"
        f"请简洁描述图像中的不良内容，涉及歧视、暴力、血腥、误导性等，"
        f"请重点判断是否包含仇恨言论、暴力、或任何有害内容。"
    )
    return prompt

# 进行情感分析，判断是否包含仇恨言论
def hateful_analysis(text):
    for keyword in keywords:
        if keyword in text:
            return "hateful"
    return "not hateful"

# 提取单个代表情感色彩的关键词
def extract_keywords(text):
    vectorizer = TfidfVectorizer(stop_words='english', max_features=1)  # 只提取最重要的一个词
    tfidf_matrix = vectorizer.fit_transform([text])
    feature_names = np.array(vectorizer.get_feature_names_out())
    return feature_names[0]  # 返回最重要的关键词

# 语义理解（BERT）: 使用BERT模型进行分析
def semantic_understanding(text):
    inputs = bert_tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    outputs = bert_model(**inputs)
    prediction = outputs.logits.argmax().item()  # 获取分类结果
    return "Positive" if prediction == 1 else "Negative"  # 假设为二分类

# 分析图像描述，返回关键词和hateful or not
def analyze_caption_with_gpt4(description, image_path):
    prompt = generate_analysis_prompt(image_path, description)

    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {API_SECRET_KEY}',
    }
    
    data = {
        "model": "gpt-4.1",
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ]
    }

    # 开始计时
    start_time = time.time()
    
    response = requests.post(BASE_URL, headers=headers, json=data)
    
    # 结束计时
    end_time = time.time()

    # 计算推理时间
    inference_time = end_time - start_time
    tokens_used = response.json().get('usage', {}).get('total_tokens', 0)
    cost = (tokens_used / 1000) * 0.03  # 假设费用为每1000个token 0.03美元

    print(f"推理时间: {inference_time:.2f}秒")
    print(f"消耗Token数量: {tokens_used}")
    print(f"推理费用: ${cost:.4f}")

    if response.status_code == 200:
        result = response.json()
        analysis = result["choices"][0]["message"]["content"]
        
        # 情感分析：判断是否为仇恨言论
        sentiment = hateful_analysis(analysis)
        
        # 关键词提取：提取情感色彩的关键词
        keyword = extract_keywords(analysis)
        
        # 语义理解：通过BERT模型进行情感理解
        semantic_analysis = semantic_understanding(analysis)
        
        # 生成summary
        summary = {
            "description": analysis,
            "sentiment": sentiment,
            "keywords": keyword,
        }

        return summary
    else:
        return f"Error: {response.status_code}, {response.text}"

# 读取文件夹中的图像并分析
def analyze_images_in_folder(folder_path, num_images=None):
    files = os.listdir(folder_path)
    image_files = [f for f in files if f.endswith(('jpg', 'jpeg', 'png', 'bmp'))]
    
    if num_images:
        image_files = image_files[:num_images]

    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        print(f"正在分析: {image_file}")
        
        description = describe_image_with_blip(image_path)
        print("生成的描述：", description)

        summary = analyze_caption_with_gpt4(description, image_path)
        
        print("分析总结：", summary)
        print('')
        print('####' * 30)
        print("")

# 主函数示例：上传图像并分析描述
def main():
    folder_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/img"
    analyze_images_in_folder(folder_path, num_images=3)

# 执行主函数
main()
# Out:
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 20867.18it/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 正在分析: 69351.png
# 生成的描述： a pig that is smiling
# 推理时间: 4.20秒
# 消耗Token数量: 249
# 推理费用: $0.0075
# 分析总结： {'description': '经分析：\n\n- 图像内容：一只正在微笑的猪。\n- 图像文字："heyimusiinmeatine!"（疑似“hey, I\'m using meat in me!”的变体）\n\n**判断：**\n该内容没有明显针对特定群体或个人的仇恨言论，也未涉及暴力、血腥等元素。图像和文字的组合不具有直接的歧视性质，没有明显误导性。整体来看没有有害内容。\n\n**结论：**\n不含仇恨言论、暴力或其他有害内容。', 'sentiment': 'hateful', 'keywords': 'hey'}
#
# ########################################################################################################################
#
# 正在分析: 17843.png
# 生成的描述： a man is working on a table in a room
# 推理时间: 7.39秒
# 消耗Token数量: 499
# 推理费用: $0.0150
# 分析总结： {'description': '分析如下：\n\n1. **图像内容**  \n图像描述为“一名男子在房间内的桌子上工作”，无明显暴力、血腥或歧视场景。\n\n2. **图像中的文字**  \n- “see? i fuckin told you a little foil on ton keeps themiju icy met mrareis best”  \n  这句话整体为英文，但后半部分“keeps themiju icy met mrareis best”语义不清晰，似为拼写混乱或乱码，“i fuckin told you”含有粗俗语言，但不构成明确的人身攻击或恶意。\n\n3. **恶意内容分析**  \n- **仇恨言论**：未检测到针对特定群体、种族、性别等的贬损、歧视言论。\n- **暴力/血腥**：未检测到与暴力或血腥相关的场景或描述。\n- **有害内容**：除去粗俗词汇外，主要内容为自言自语式语句，无明显煽动、误导或伤害倾向。\n- **误导性**：文本语义整体不明确，难以导致误导和错误理解。\n\n4. **结论**  \n该图像及其文字**未检测到明显的仇恨言论、暴力、歧视或其他有害内容**，但包含一定的不文明用语（fuckin），建议根据平台规范对粗俗用语做适当处理。\n\n**综合判定：不包含仇恨言论或有害内容。**', 'sentiment': 'hateful', 'keywords': 'fuckin'}
#
# ########################################################################################################################
#
# 正在分析: 27980.png
# 生成的描述： a little girl kissing a little girl
# 推理时间: 8.33秒
# 消耗Token数量: 350
# 推理费用: $0.0105
# 分析总结： {'description': '经分析，图像内容为“两位小女孩亲吻”，图像文字为“when the vegetables”（意为“当蔬菜……”，文字不完整）。  \n根据提供信息：\n\n- **是否存在仇恨言论、歧视、暴力或其他有害内容**：  \n  仅就当前描述和文字判断，图像未明确表现仇恨言论、歧视、暴力、血腥成分或明显的误导性内容。\n- **潜在风险**：  \n  如果“when the vegetables”后续出现与图像结合有攻击性、歧视性、或侮辱同性恋/女童等补充内容，才有可能形成有害语境。但以现有信息无法得出结论。\n\n**总结**：  \n当前图像及文字未直接显示任何歧视、暴力、血腥或仇恨言论。不构成有害内容。\n\n如需全面判断，需补充完整文字信息或结合更广泛上下文分析。', 'sentiment': 'hateful', 'keywords': 'vegetables'}
#
# ########################################################################################################################

# %% [markdown]
# ### BLIP-based Level-4: Structured Output

# %%
import openai
import os
import requests
from PIL import Image
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration, BertTokenizer, BertForSequenceClassification
import pytesseract  # 用于OCR（文字识别）
import time
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# 设置API密钥和URL
API_SECRET_KEY = "sk-zk21884c49fc398427914f99fc30171ecb068f998dc6f05b"
BASE_URL = "https://api.zhizengzeng.com/v1/chat/completions"

# 加载BLIP模型和处理器
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 加载BERT模型（用于语义理解）
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

# 扩展的细粒度关键词列表（多模态信息捕捉的关键细节）
captions_keywords = [
    '暴力', '攻击', '恐怖主义', '战争', '杀戮', '残忍',
    '种族歧视', '性别歧视', '年龄歧视', '贫富差距', '身体歧视', '宗教歧视', 
    '同性恋歧视', '外貌歧视', '血腥', '凶杀', '残忍行为', '血腥场面',
    '谣言', '假新闻', '恶意炒作', '虚假信息', '误导性广告',
    '仇恨', '恶意攻击', '恶性竞争', '污蔑', '恶意散布',
    '不道德', '不正当手段', '欺诈', '贪婪', '非法活动', '敲诈', '诈骗',
    '仇恨言论', '仇恨犯罪', '排外', '性别仇恨', '宗教仇恨',
    '精神虐待', '心理操控', '精神暴力', '霸凌', '讽刺', '贬低',
    '毒品', '吸毒', '暴饮暴食', '酗酒', '赌博',
    '淫秽内容', '色情', '淫秽语言', '性骚扰', '侵犯隐私',
    '贫困', '贫困歧视', '社会不公', '政治迫害', '暴政',
    '极端主义', '极右翼', '极左翼', '民族主义', '恐怖主义意识形态'
]

# 加载图像并进行处理
def load_image(image_path, resize=True):
    image = Image.open(image_path)
    if resize:
        image = image.resize((512, 512))  # 调整图像大小以加速处理
    return image

# 图像文字识别函数（OCR）
def extract_text_from_image(image_path):
    image = load_image(image_path)
    text = pytesseract.image_to_string(image)  # 使用tesseract进行OCR
    return text.strip()  # 返回图像中的文字内容

# 使用BLIP生成图像描述
def describe_image_with_blip(image_path):
    image = load_image(image_path)
    inputs = processor(image, return_tensors="pt")
    out = model.generate(**inputs)
    description = processor.decode(out[0], skip_special_tokens=True)
    return description

# 生成分析内容的Prompt
def generate_analysis_prompt(image_path, description):
    text_from_image = extract_text_from_image(image_path)
    prompt = (
        f"假如你是一位具有非常丰富经验的心理学家、社会学家，现在需要完成**Facebook Hateful Memes Detection**任务，"
        f"请综合分析以下图像内容与图像中的文字信息，特别关注图像和文字的融合信息，考虑到它们如何共同表达和加强潜在的情感和信息：\n"
        f"图像描述：{description}\n"
        f"图像中的文字：{text_from_image}\n"
        f"请结合图像的视觉内容和文字的语义信息，从以下几个维度进行分析：\n"
        f"- 图像和文字如何共同构建整体信息？\n"
        f"- 这张图像和文字结合后是否传递出歧视、暴力、血腥、误导性等不良内容？\n"
        f"- 结合图像与文字的信息，是否存在仇恨言论、暴力、或任何有害的暗示？\n"
        f"请特别关注图像和文字如何相互作用以及它们对情感色彩的共同影响。"
    )
    return prompt

# 进行情感分析，判断是否包含仇恨言论
def hateful_analysis(text):
    detected_keywords = []
    for keyword in captions_keywords:
        if keyword in text:
            detected_keywords.append(keyword)
    return detected_keywords if detected_keywords else ["not hateful"]

# 提取多个情感色彩关键词
def extract_keywords(text):
    vectorizer = TfidfVectorizer(stop_words='english', max_features=5)  # 提取最重要的前5个关键词
    tfidf_matrix = vectorizer.fit_transform([text])
    feature_names = np.array(vectorizer.get_feature_names_out())
    return feature_names  # 返回多个关键词

# 语义理解（BERT）: 使用BERT模型进行分析
def semantic_understanding(text):
    inputs = bert_tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    outputs = bert_model(**inputs)
    prediction = outputs.logits.argmax().item()  # 获取分类结果
    return 1 if prediction == 1 else 0  # 输出1代表包含仇恨，0代表没有

# 分析图像描述，返回关键词和hateful or not
def analyze_caption_with_gpt4(description, image_path):
    prompt = generate_analysis_prompt(image_path, description)

    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {API_SECRET_KEY}',
    }
    
    data = {
        "model": "gpt-4.1",
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ]
    }

    # 开始计时
    start_time = time.time()
    
    response = requests.post(BASE_URL, headers=headers, json=data)
    
    # 结束计时
    end_time = time.time()

    # 计算推理时间
    inference_time = end_time - start_time
    tokens_used = response.json().get('usage', {}).get('total_tokens', 0)
    cost = (tokens_used / 1000) * 0.03  # 假设费用为每1000个token 0.03美元

    print(f"推理时间: {inference_time:.2f}秒")
    print(f"消耗Token数量: {tokens_used}")
    print(f"推理费用: ${cost:.4f}")

    if response.status_code == 200:
        result = response.json()
        analysis = result["choices"][0]["message"]["content"]
        
        # 情感分析：判断是否为仇恨言论
        sentiment = hateful_analysis(analysis)
        
        # 关键词提取：提取情感色彩的关键词
        keywords_list = extract_keywords(analysis)
        
        # 语义理解：通过BERT模型进行情感理解
        semantic_analysis = semantic_understanding(analysis)
        
        # 生成summary
        summary = {
            "description": analysis,
            "sentiment": sentiment,
            "keywords": keywords_list,
            "semantic_analysis": semantic_analysis,
        }

        return summary
    else:
        return f"Error: {response.status_code}, {response.text}"

# 读取文件夹中的图像并分析
def analyze_images_in_folder(folder_path, num_images=None):
    files = os.listdir(folder_path)
    image_files = [f for f in files if f.endswith(('jpg', 'jpeg', 'png', 'bmp'))]
    
    if num_images:
        image_files = image_files[:num_images]

    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        print(f"正在分析: {image_file}")
        
        description = describe_image_with_blip(image_path)
        print("生成的描述：", description)

        summary = analyze_caption_with_gpt4(description, image_path)
        
        print("分析总结：", summary)
        print('')
        print('####' * 30)
        print("")

# 主函数示例：上传图像并分析描述
def main():
    folder_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/img"
    analyze_images_in_folder(folder_path, num_images=10)

# 执行主函数
main()
# Out:
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 17549.39it/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 正在分析: 69351.png
# 生成的描述： a pig that is smiling
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 15.89秒
# 消耗Token数量: 1384
# 推理费用: $0.0415
# 分析总结： {'description': "我们来综合分析你提供的图片描述和文字内容，从心理学与社会学角度审视其潜在影响过程：\n\n---\n\n### 1. 图像和文字如何共同构建整体信息？\n\n- **视觉内容分析**：\n  - 图片是一只正在微笑的猪。从心理学角度，猪微笑通常营造一种友好、可爱的氛围，容易引发观众的亲切感或共鸣。\n  - 猪在文化语境中有多重象征意义，既可以是纯粹的动物，也可能隐含更多社会层面的隐喻（比如“贪吃”、“脏乱”或“牺牲”等）。\n\n- **文字内容分析**：\n  - 文字内容为“heyimusiinmeatine!”。这看似是在表达“Hey, I’m usin’ me at ine!”，“ I’m using me at ine!”等，尝试拆解可以推测是“Hey, I’m used in meat, ine!”（我被用于肉中），或更接近“Hey, I’m in meat, nine!”（我在肉里，九？）\n  - 更有可能是“Hey, I’m usin' meat in!”（嘿，我在用肉）或“Hey, I’m a pig in meat!”（嘿，我是肉中的猪），但拼写有明显错漏，也可能是网络用语或恶搞风格。\n\n- **信息融合分析**：\n  - 微笑的猪+与“meat”相关的语句，容易让观众联想到猪的命运（通常是被屠宰之后成为肉类食物），类似讽刺或黑色幽默。\n  - 图像和文字产生的融合信息是“这只猪以自我调侃的语气，谈论自己作为肉类存在”的角色。\n\n---\n\n### 2. 该内容是否传递出歧视、暴力、血腥、误导性等不良信息？\n\n- **歧视性**：\n  - 并未针对任何人群或社会群体表达歧视，主题聚焦在动物（猪）本身，无指向性的社会歧视。\n- **暴力与血腥**：\n  - 图像未含暴力或血腥场面，仅是一只微笑的猪。\n  - 虽然文字隐晦提及“meat”，间接暗示猪的命运，但未出现任何直白描述屠宰过程或血腥画面，整体表达更偏向幽默或讽刺。\n- **误导性**：\n  - 文字表达模糊，拼写不规范，可能让部分人难以一眼理解，但若理解为“猪在开玩笑自己会成为肉”，并不具备误导性，只是略显黑色幽默。\n\n---\n\n### 3. 是否存在仇恨言论、暴力、或任何有害的暗示？\n\n- **仇恨言论**：\n  - 没有针对特定团体、种族、性别或其他身份的仇恨言论。\n  - 图像和文字均未带有明显攻击性语调。\n- **有害暗示**：\n  - 虽然文中带有“meat”与猪有关的讽刺，可能让关注动物伦理的人不适，但从主流角度仅是黑色幽默，没有伤害性语言。\n  - 没有引导暴力行为或进行恶意煽动。\n\n---\n\n### 4. 情感色彩与社会心理影响\n\n- **情感色彩**：\n  - 微笑的猪形象具有积极、轻松的色彩，能够缓解敏感话题的紧张感。\n  - 文字表达是恶作剧/讽刺性质，用自我调侃方式表述，整体更加幽默而非严肃或悲伤。\n- **社会心理影响**：\n  - 对大多数受众来说，这张图像融合后的信息只是带有“食物-动物”关系下的黑色幽默，未形成明显负面情绪。\n  - 但对某些动物保护主义者可能引发不适，因揭示了猪作为肉类的命运，但并未失控为仇恨或煽动类内容。\n\n---\n\n## 结论\n\n综合图像和文本信息：\n- **该内容整体表现为幽默或讽刺，没有明显的歧视性、暴力、血腥或误导性。**\n- **不存在仇恨言论，也没有煽动暴力或其他有害暗示；其对情感色彩的主导作用是调侃与幽默。**\n- 图像与文字的结合，让受众在轻松氛围下思考动物作为食物的命运，但缺乏攻击性和贬低某一群体的行为。\n\n### 结论性判定（Facebook Hateful Memes Detection 语境下）：\n**此内容不属于仇恨型、不良型或有害型 meme，整体为无害的幽默或讽刺表达。**\n\n如需进一步判别或更细致分析，可以补充上下文或受众信息，以确保结论全面。", 'sentiment': ['暴力', '攻击', '血腥', '血腥场面', '仇恨', '仇恨言论', '讽刺', '贬低'], 'keywords': array(['hey', 'ine', 'meat', 'usin', '暴力'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 17843.png
# 生成的描述： a man is working on a table in a room
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 12.77秒
# 消耗Token数量: 1165
# 推理费用: $0.0350
# 分析总结： {'description': '根据你给出的图片和文字信息，以下是从心理学与社会学角度进行的综合分析：\n\n---\n\n### 一、图像与文字的融合分析\n\n**1. 图像信息**\n- 描述：一个男性在室内的桌子旁工作。\n- 情感氛围：该类场景通常较为中性，可能展现专注、平和，或普通的日常生活状态，并不明显带有任何负面、暴力或极端色彩。\n\n**2. 文字信息**\n- 内容：  \n  "see? i fuckin told you a little foil on ton  \n  keeps themiju  \n  icy met mrareis best"\n\n- 语义解析：\n  - 首句为："see? i fuckin told you a little foil on ton"。语气带有口语化及轻微粗俗（f***in），表达一种强调或得意的情绪。内容似乎指在某处放少许锡纸（foil）可以起到某种作用，"on ton"可能是拼写或打字误误，难以精确理解。\n  - 第二、三句语义不清： "keeps themiju", "icy met mrareis best"。这些词组未能与标准英语或常见俚语相对应，也未能直接体现出有害情绪或仇恨内容，更像是杂乱或玩笑式拼写。\n\n**3. 图像与文字融合**\n- 图像与文字共同传达的是个人（男性）在进行某种行为，他告诉别人：他的做法（涉及锡纸）“很管用”。文字中略带小骄傲和粗鲁，但没有具体指向某一群体或人。\n- 视觉内容未表现暴力、血腥、强烈冲突，与文字结合也未形成强烈负面情绪的图像——没有明显的歧视暗示，没有象征仇恨的符号或动作。\n\n### 二、不良内容与仇恨言论分析\n\n- **歧视**：未出现针对性人群、种族、性别、宗教等的贬低或嘲讽。\n- **暴力、血腥**：视觉无暴力场面，文字无暴力威胁或鼓动。\n- **误导性**：文字部分不甚清晰，可能是网络梗或无头绪的拼写，但并没有表现误导或危险行为。\n- **仇恨言论/有害暗示**：文字中虽有轻微粗口（fuckin），但该词在很多轻松幽默的语境下出现。没有针对具体对象的攻击或侮辱。整体表达偏向幽默或日常自夸，而非有害的社会言论。\n\n### 三、情感色彩与社会影响\n\n- 情感色彩上，图像本身较中性，文字虽有强调但未体现明显激烈负面情感。唯一突出的是使用了粗口，有可能让部分受众感受到不适，但在社交平台常见语境下未超出正常幽默或夸张表达范围。\n- 社会影响方面，未发现散播仇恨、煽动暴力、引导错误行为的迹象。\n- 图像和文字共同作用下，内容更像个人经验炫耀或调侃生活小窍门，并未演变为有害表达。\n\n---\n\n## 综合结论\n\n- **图像与文字共同表达的信息偏向普通生活、自我表达、娱乐化。**\n- **没有构成歧视、仇恨言论或其他有害内容。**\n- **情感色彩以调侃、自我夸耀为主，虽然使用了粗口但在整个语境中不构成社交平台的违规。**\n\n**结论：该图像与文字的融合内容未体现仇恨、暴力、歧视、误导或其他有害信息。可以判定为非Hateful Meme。**\n\n如需进一步分析或聚焦具体语境、隐含意义，还可结合评论区、历史背景等做更深入探讨。', 'sentiment': ['暴力', '攻击', '血腥', '仇恨', '仇恨言论', '贬低'], 'keywords': array(['best', 'foil', 'fuckin', 'ton', '暴力'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 27980.png
# 生成的描述： a little girl kissing a little girl
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 11.69秒
# 消耗Token数量: 1147
# 推理费用: $0.0344
# 分析总结： {'description': '作为一位经验丰富的心理学家和社会学家，针对你所提供的“Facebook Hateful Memes Detection”任务，这里将综合分析该图像内容与文字信息，并特别聚焦于多模态融合、情感表达和潜在不良内容的评估。\n\n---\n\n## 1. 图像和文字如何共同构建整体信息？\n\n- **图像内容**：\n  - 描述中，两位小女孩亲吻，看起来是温馨、友好的场景，传递出纯真的爱和友谊。\n  - 视觉氛围通常是积极、无害的，容易让人联想到亲情、友情或天真烂漫。\n\n- **文字内容**：\n  - 图中文字 “when the vegetables” 语义上不完整，通常在社交媒体和梗文化中，类似的句式是用作某种情节的铺垫（如“when …”后接特定事件或反应）。\n  - 单独考察，“when the vegetables”缺乏明确的指向性和情感色彩，尚未表达完整的态度或情绪。\n\n- **融合分析**：\n  - 当前图文组合下，二者之间没有直接构成联想或反差。小女孩亲吻和“when the vegetables”在内容和情感色彩上没有明显的连接或冲突。\n  - 融合后，用户未必能直观地推断出特定的深层信息。很可能是未完成的或省略了后续部分的网络梗。\n\n---\n\n## 2. 图像和文字结合后是否传递出不良内容？\n\n- **歧视/仇恨/暴力/血腥/误导性**：\n  - 当前所提供的信息，无论是图像还是文字，都没有明示或暗示任何歧视、仇恨、暴力或血腥成分。\n  - 影像温馨，文字看似无害，未搭建出负面语境。\n\n- **误导性分析**：\n  - 图文表达都较为模糊，未能产生误导性信息，对受众不会造成认知偏差或激发负面情绪。\n\n---\n\n## 3. 是否存在仇恨言论、暴力或其他有害暗示？\n\n- **结合分析**：\n  - 小女孩亲吻的行为本身属于童真、无害的表达，不涉及任何边缘、引战或有害的行为。\n  - “when the vegetables”作为片段式文字，无完整语义或具体对象，缺乏攻击性、排斥性或令人不适的暗示。\n  - 如果后续补充了恶意内容（如某些网络梗有时会用“vegetables”暗指某种群体或事件），理论上可能涉及，但根据你提供的图文，当前无此迹象。\n\n---\n\n## 4. 图像和文字相互作用及情感色彩影响\n\n- 在这个案例中，图像的情感色彩主要是正向、温馨和纯真。\n- 文字单独被提取，相对中性，无法激发强烈情感。\n- 二者结合后，并未产生负面暗示，更没有加强任何仇恨、歧视或暴力元素。\n\n---\n\n## 结论\n\n基于目前你提供的多模态信息，“a little girl kissing a little girl”与“when the vegetables”融合后，未构建出任何明显的不良内容、仇恨暗示或有害信息。整体情感色彩偏向中性或正向，未形成对特定群体或个人的攻击、歧视、暴力等负面效应。\n\n**建议**：对于类似未完成或语义含糊的文字，如后续补充或解释，请进一步审查其完整表达和潜在网络语境，确保无隐性歧视、恶意或误导性内容。\n\n---\n\n如需对更具体的网络语境、特定用词暗示或深度语义分析，欢迎补充更多背景信息，便于进行更细致的心理学和社会学风险评估。', 'sentiment': ['暴力', '攻击', '血腥', '仇恨', '仇恨言论'], 'keywords': array(['girl', 'little', 'vegetables', '仇恨', '歧视'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 24537.png
# 生成的描述： a little boy is running with a sponge sponge sponge sponge sponge sponge sponge sponge sponge sponge sponge sponge sponge
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 10.61秒
# 消耗Token数量: 1018
# 推理费用: $0.0305
# 分析总结： {'description': '以下是针对**Facebook Hateful Memes Detection**任务所做的综合分析：\n\n---\n\n### 1. 图像和文字如何共同构建整体信息？\n\n**视觉内容分析**：  \n- 图像描述是一位小男孩正在奔跑，并且伴随有多次重复的单词“sponge”（海绵）。\n- 没有特殊环境描述（例如暴力场景、血腥元素或异常表情），仅看到孩童活动。\n\n**文字语义分析**：  \n- 图像中的文字为重复的“sponge”——没有明显的语法结构或内涵，只是机械重复。\n- “Sponge”本身语义中性，通常无恶意、不包含有害元素。\n\n**整体交互分析**：  \n- 图像中的文字与画面内容并无冲突，未出现双关、暗示、或强烈指涉。\n- 共同作用下，用户主要感知到的可能是孩子在与“海绵”相关的活动（比如玩具、清洁等），没有明确的攻击性或刺激性信息。\n\n---\n\n### 2. 这张图像和文字结合后是否传递出歧视、暴力、血腥、误导性等不良内容？\n\n- **歧视**：无任何种族、性别、宗教或其他群体暗示，未出现贬低或歧视表达。\n- **暴力/血腥**：图像为小男孩奔跑，没有显现肢体暴力、血腥、受伤、恐吓等元素。\n- **误导性**：重复的“sponge”词汇虽然不明其用意，但并未让受众产生错误认知、误导他人或传递虚假信息。\n- **其它不良内容**：整体内容健康、无攻击性元素。\n\n---\n\n### 3. 结合图像与文字的信息，是否存在仇恨言论、暴力或任何有害的暗示？\n\n- 没有直接或间接的仇恨言论——无针对个人或群体的负面指向。\n- 无暴力内容——画面和文字均未提及或暗示暴力行为。\n- 没有关联有害暗示——词汇为“sponge”，无恶意双关或隐喻。\n\n---\n\n### 4. 情感色彩分析：图像和文字如何相互作用？\n\n- **中性或积极**：孩子奔跑本身易让人联想到活泼和运动，海绵通常与日常生活或玩耍相关。未加入负面情感。\n- **无情绪强化**：文字的重复“sponge”未对情感色彩有明显的强化作用，这种机械式重复更偏向幽默或无厘头，而非负面。\n\n----\n\n## 总结结论\n\n**图像内容与文字均未体现歧视、暴力、血腥、误导或仇恨性信息，二者无害，共同作用未带来任何有害社会影响。**\n\n在Facebook Hatefu Memes检测任务中，该样本应被判定为**非仇恨、不有害内容**（non-hateful），无需进一步警示或干预。\n\n---\n\n**扩展说明**：  \n作为心理与社会学专业人员，也需保持警惕，对极端重复、异常单词组合等类型持续关注，以防隐晦表达的潜在风险。但本案例经过综合分析后，未见任何隐性伤害、不良暗示或有害内容。', 'sentiment': ['暴力', '攻击', '血腥', '虚假信息', '仇恨', '仇恨言论', '贬低'], 'keywords': array(['hateful', 'sponge', '暴力', '海绵', '血腥'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 53967.png
# 生成的描述： a child is holding a can of coke
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 15.61秒
# 消耗Token数量: 1097
# 推理费用: $0.0329
# 分析总结： {'description': '好的，下面作为具有丰富经验的心理学家和社会学家，针对**Facebook Hateful Memes Detection**任务，就你提供的内容作专业分析。\n\n## 一、图像和文字如何共同构建整体信息？\n\n**视觉内容**：“一个孩子正在拿着一罐可口可乐。”\n**文字内容**：未给出具体文字，仅知图像中的文字为“图像中的文字”。\n\n在判断 hateful meme 时，核心是文本与图像的**结合**是否构建了有害、歧视、误导或仇恨的信息。\n\n**分析：**\n- 图像本身是一个孩子拿着一罐可乐。这是一幅生活场景，具有普遍性和中性特征，不具备明显的负面或敏感情绪。\n- 如果文字部分为中性或对应描述，比如“快乐时光”或“孩子享受清凉饮料”，那么图像与文字共同表达的是友善和日常生活的场景，情感色彩是正面或中性。\n- 如果文字部分带有隐含信息，如“可乐让孩子变得不听话”或“孩子只喜欢垃圾食品”，则图像与文字开始形成轻度的负向情感，但通常不构成仇恨或有害言论。\n\n## 二、是否传递出歧视、暴力、血腥、误导性等不良内容？\n\n在你给出的信息里，图像是正常、健康的生活场景，没有暴力、血腥内容。  \n对图片本身而言：\n- 不涉及**歧视**：没有针对某群体、某性别、某种族的攻击。\n- 不涉及**暴力/血腥**：孩子与饮料，没有任何暴力或受伤场景。\n- 不存在**误导性**：只要文字部分不是虚假宣传或绑定负面标签，则没有明显具误导性。\n\n## 三、是否存在仇恨言论、暴力或有害暗示？\n\n根据你当前描述（纯图片内容和普通文字），**没有发现仇恨、暴力或有害的暗示**。  \n当然，最终判定还需看文字内容的具体表达。比如：\n- 如果文字为“我们不需要像这样喝可乐的孩子”，形成了轻微的否定语气，仍不构成仇恨或歧视，只是个人观点。\n- 如果文字为“只有某某才会喝这种东西”并带有侮辱、刻板印象，则需警惕是否具歧视性。\n- 当前描述未见任何有害暗示。\n\n## 四、图像与文字互相作用对情感色彩的影响\n\n- 图像和文字如都为积极或中性，则情感色彩为中立或积极。\n- 图像为中性，文字为负性，则整体内容需留意是否引导观众对某群体、事物产生敌意。\n- 当前场景下，二者结合未有负向、仇恨或误导色彩。\n\n## **结论总结**\n\n基于图像内容（一个孩子拿可乐）和普通表述，下述结论：\n- **未发现歧视、仇恨、暴力、血腥、误导、有害暗示或仇恨言论。**\n- 图像与文字结合对受众的情感影响为中性或轻度积极。\n- 除非文字添加特殊有害信息，否则该内容不构成 Hateful Meme，也不符合 Facebook hateful memes 标注标准。\n\n**补充说明**：如需进一步细化情感分析或对具体文字版本进行判断，可再补充文字内容，我可更精准评估其融合表达对情感和社会影响方面的细节及风险。\n\n---\n\n**结论：此图像与文字不涉嫌不良内容，也不会激发仇恨、暴力或有害暗示，属于安全、健康内容。**', 'sentiment': ['暴力', '攻击', '血腥', '仇恨', '仇恨言论'], 'keywords': array(['hateful', '不涉及', '暴力', '比如', '血腥'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 29013.png
# 生成的描述： a man with a white turba
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 43.70秒
# 消耗Token数量: 1447
# 推理费用: $0.0434
# 分析总结： {'description': '当然！下面我将以心理学与社会学视角，结合**Facebook Hateful Memes Detection**的分析要求，对该样例进行全面剖析。\n\n---\n\n### 1. **图像和文字如何共同构建整体信息？**\n\n- **图像内容**：描述为“一位戴着白色头巾的男性”。此类视觉描述在全球范围内涉及诸多文化（如南亚、中东、非洲等），白色头巾在某些文化中象征宗教或民族身份，常与锡克教、伊斯兰教等群体相关。\n- **文字内容**：并未提供具体文字，仅描述为“图像中的文字”。\n\n由于没有具体给出图片内的文字内容，分析主要聚焦于**图像内容**和**潜在文字内容的语境融合**。\n\n- **潜在互动**：\n    - **中立型**：纯粹展示服饰与身份，不带引导性或倾向性的话语。\n    - **带倾向性**：若文字带有“某些指控、定性、嘲讽、污蔑”等，则可能引导观者以特定方式解读该形象。\n\n### 2. **图像与文字结合后是否传递不良内容？**\n\n- **歧视风险**\n    - 如果文字是中性陈述（如“他正在庆祝节日”），则与图像配合不会传递负面、歧视、暴力或误导性内容。\n    - 如果文字暗示与该群体关联的负面刻板印象或负面新闻，则有可能通过“图像+文字”的方式，强化、放大特定族群的污名化，例如，把特定装束与极端、犯罪、落后等字眼关联。\n\n- **误导性风险**\n    - 若文字利用该形象引申到一个真实无关的消极事件（如将某人形象用于犯罪新闻配图），就会有严重的误导性。\n\n- **暴力内容**\n    - 仅凭服饰形象本身不足以判定暴力意图，但如果文字中涉及“呼吁排斥、暴力、歧视、直接攻击”这类措辞，结合具体人像，就属于明显的仇恨表达。\n\n### 3. **结合图像与文字的信息，是否存在仇恨、暴力或有害暗示？**\n\n- **仇恨言论甄别方法**：\n    - 需关注**文字是否指出该人物/群体应受到差别对待或贬低**，或者是否**将该外观与危险、低劣、敌对等负面形容词挂钩**。\n    - 日常的宗教、民族穿着，若未被文字赋予负向语境，情感色彩倾向中性甚至正向。但一旦出现损害名誉、挑起敌意、鼓励排斥、贬低、嘲弄、威胁、攻击性用词，就符合仇恨、暴力或有害的暗示。\n\n- **实际案例说明**：\n    - 例如，图像为“戴白色头巾的男性”，文字为“这才是恐怖分子的真面目”——这种语境下，显著构成种族/宗教仇恨煽动。\n    - 如果文字为“传统服饰之美”，则并无明显伤害成分，甚至传递尊重与包容。\n\n### 4. **情感色彩与融合效应**\n\n- **图像本身的情感色彩**：一般为中性或因视觉表情等有所变化，更多依赖文字给出的线索进一步诠释。\n- **融合效应**：受文字主导。文字如果提供中性或正面情感解读（如团结、包容、文化多元等），则整体没有攻击性。但如果文字拆解、丑化，便极易把图像用于特定标签传播，从而强化偏见和恶意。\n\n---\n\n## **总体结论（专家建议）**\n\n- **单独的“戴白色头巾的男性”图像并无固有恶意。**\n- **是否构成不良内容、仇恨言论、暴力或暗示，关键看与之搭配的**文字内容到底是何种语义**。**\n\n### **如果你执行自动检测任务，一定要：**\n1. 精细抓取和分析文字中是否有针对群体身份（如宗教、民族、地域）的贬损性、排他性、煽动性、攻击性言论。\n2. 结合图像识别的群体符号，一旦语言暗示负面，即需高度警惕，并按平台规范作出惩戒。\n3. 注意误导性表达，防范“移花接木”或“断章取义”等利用图像身份误导受众的风险。\n4. 人工审核时，结合语境和图像本身的文化象征意义，预防算法误报，避免对正常文化表达造成不公。\n\n---\n\n### **总结句：**\n***图像+文字的结合可被用于强化文化、宗教、群体的正向包容，也极易被滥用为仇恨、歧视传播工具。关键在于文字具体内容及其与图像的组合语境，只有综合考量才能有效识别与应对有害信息。***', 'sentiment': ['暴力', '攻击', '仇恨', '污蔑', '仇恨言论', '宗教仇恨', '贬低'], 'keywords': array(['例如', '图像', '图像内容', '戴白色头巾的男性', '歧视'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 10692.png
# 生成的描述： a group of men standing together with the words, this guy wants to say have wonderful day
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 14.25秒
# 消耗Token数量: 1129
# 推理费用: $0.0339
# 分析总结： {'description': '好的，以下是针对**Facebook Hateful Memes Detection**任务，结合心理学、社会学视角及仇恨言论检测的综合分析：\n\n---\n\n### 1. 图像和文字如何共同构建整体信息？\n\n**视觉内容：**  \n根据描述，图中是一群男性站在一起。这类群体形象常用于表示社区、友谊、团队或某种集体感。\n\n**文字信息：**  \n文字内容是“this guy wants to say have wonderful day”（这个人想说‘祝你度过美好的一天’）。这是一句非常正面的、充满善意的表达，没有任何暗示或直接的负面情感。\n\n**融合分析：**  \n图像中的男性群体+温和友善的问候语——两者结合后所传达的信息整体上偏向积极：展现了某个人（或是整个团队）想要表达善意和友好。这种组合在情感上唤起的是温暖、积极、乐观，甚至有社交鼓励的意味。\n\n---\n\n### 2. 图像与文字结合后是否传递不良内容（歧视、暴力、血腥、误导性等）？\n\n**分析：**\n- **歧视倾向：** 单凭描述，没有体现对任何群体的负面态度。\n- **暴力/血腥元素：** 无任何关于暴力或血腥事件的直观描绘。\n- **误导性信息：** 文字与图片并无明显冲突，不存在对事实的严重歪曲，没有讽刺或双关语可以被解读为误导。\n- **仇恨/激进表达：** 一句话“have wonderful day”，本身极为中性和善意，没有引发骚动或冒犯的空间。\n\n**总结：**  \n图文结合并未传递出任何明显的不良内容，属于安全、含义直接的表达。\n\n---\n\n### 3. 是否存在仇恨言论、暴力或任何有害暗示？\n\n**深度社会&心理学分析：**\n- **图像语境：** 群体照片某些情况下 *可能* 在特定文化背景下触发生理或身份标签的暗示，但如此描述下，没有性别歧视、种族歧视或特定身份攻击的线索。\n- **文字语境：** 所有文字信息皆为积极友好的问候，无攻击性或讽刺色彩。\n- **融合信息风险评估：** 在现实的 meme 环境中，仇恨言论往往依靠图像和文字间的反差或讽刺、多义语境，但当前例子未体现这种动态。\n\n**情感色彩影响：**  \n整体讯息唤起善意、积极情感，无任何引起焦虑、愤怒、恐惧等负面情绪的暗示。\n\n---\n\n### 4. 图像与文字的相互作用及对情感色彩的共同影响\n\n- 文字本身拥有极强的正面情感推动力，结合群体形象，进一步放大了包含和善的社交信号。\n- 没有任意移情、讽刺或歧义用词。\n- 图像并未削弱文字情感，反而增强了其群体认可和共同性，传递正能量。\n\n---\n\n## 综合结论\n\n从心理学、社会学与仇恨言论检测的专业标准来看，该图像及其文字结合：\n\n- 无任何歧视、暴力、血腥、误导性信息。\n- 没有仇恨言论、侮辱或有害暗示。\n- 情感色彩为正面，增强友善和社交积极性。\n- **判定该图像与文字内容完全不构成仇恨、不良内容，对大众情绪和认知无负面影响。**\n\n**推荐分类：安全/无害内容。**\n\n如果需要进一步细化分析或有其他语境补充，欢迎告知。', 'sentiment': ['暴力', '攻击', '种族歧视', '性别歧视', '血腥', '仇恨', '仇恨言论', '讽刺'], 'keywords': array(['day', 'wonderful', '暴力', '血腥', '误导性信息'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 79624.png
# 生成的描述： a small owl sitting on a wooden post
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 10.63秒
# 消耗Token数量: 1096
# 推理费用: $0.0329
# 分析总结： {'description': '作为一名经验丰富的心理学家和社会学家，针对**Facebook Hateful Memes Detection**任务，以下是对所提供素材——一张“小猫头鹰坐在木桩上”的图片及其图像中的文字——从融合信息、情感色彩与潜在风险角度的专业分析：\n\n---\n\n### 一、图像和文字如何共同构建整体信息？\n\n1. **视觉信息：**\n   - 画面主体为“小猫头鹰”，坐在木桩上，属于自然、可爱的动物形象。\n   - 小猫头鹰通常被大众视为温和、聪明、富有灵性的象征，画面整体传递着宁静和自然之美。\n   \n2. **文字信息：**\n   - 目前仅给出图片描述，无具体文字内容。（如果图片中的文字与图片描述一致，例如：“a small owl sitting on a wooden post”，则语义为中性、客观的事实陈述。）\n\n3. **整合分析：**\n   - 视觉内容与描述性或中性语句相搭配，仅在描述现实，没有虚构或强化额外情感色彩。\n   - 图文共同表达出中性、温和的整体信息，突出自然、动物之美与宁静氛围，不含贬损、挑衅或极端情感色彩。\n\n---\n\n### 二、是否传递出歧视、暴力、血腥、误导性等不良内容？\n\n- **歧视性分析：** 图像为动物，无涉及特定群体或隐喻，文字也未体现任何针对个人或群体的歧视意图。\n- **暴力与血腥分析：** 图片和文字均无暴力场景、血腥元素；猫头鹰静止于木桩，完全不具备威慑性或恐怖色彩。\n- **误导性分析：** 若文字仅为描述性陈述，则与画面内容一致，无误导成分；不存在通过图文搭配引导受众产生错误认知的迹象。\n\n---\n\n### 三、是否存在仇恨言论、暴力、或任何有害的暗示？\n\n- **仇恨言论：** 未体现针对任何个体或群体的攻击、侮辱、污名化言语。\n- **暴力暗示：** 画面安静祥和，绝无威胁、暴力或强迫暗示。\n- **其他有害暗示：** 无侮辱、性别、种族、文化暗示，天然、无害。\n\n---\n\n### 四、图像与文字对情感色彩的共同影响\n\n- 图文融合的整体效果为亲切、自然、平和，无显著情感激化或负面情绪引导。\n- 受众更易联想到自然、可爱、温和，激发好感，而非恐惧、愤怒或不安等负面心理。\n\n---\n\n### 总结结论\n\n**综合判断：**  \n本案例中的图片（小猫头鹰坐在木桩上）与文字描述（无明显歧视或攻击性内容）共同构建的整体信息是中性至积极的，没有任何歧视、仇恨、暴力、误导或其他有害内容。二者的结合强化温和、自然之美的意象，对情感色彩的引导是良性无害的。因此，该素材不属于“hateful meme”范畴，在网络环境中属于低风险内容。\n\n---\n\n**建议：**  \n如对侦测模型进行训练，可将此类内容归为“安全/非仇恨”类别，为算法提供正面样本基准。使用时还需配合样本多样性与实际语境，要关注文字内容是否可能随场景变化而扭曲含义。\n\n---\n\n如需进一步分析其他具体文字或图片，请补充详细信息以便更精准判断。', 'sentiment': ['暴力', '攻击', '血腥', '仇恨', '仇恨言论'], 'keywords': array(['detection', 'hateful', '小猫头鹰坐在木桩上', '暴力', '没有虚构或强化额外情感色彩'],
#       dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 20751.png
# 生成的描述： a girl with a smile and a capt that says, i ' m ' m ' m ' m
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 26.10秒
# 消耗Token数量: 1465
# 推理费用: $0.0440
# 分析总结： {'description': '作为一名经验丰富的心理学家和社会学家，针对您描述的**Facebook Hateful Memes Detection**任务，我将系统地分析该图像及其搭配文字的信息构建机制与潜在情感影响：\n\n---\n\n### 一、图像和文字如何共同构建整体信息？\n\n**1. 图像视觉内容：**  \n- 图像主体是一位女孩，她在微笑，戴着帽子，帽子上写有“I \' m \' m \' m \' m”（英文字母上的撇号重复）。  \n- 这一造型本身偏中性，无明显带有情绪指向或者象征性特征。\n\n**2. 图像中的文字内容：**  \n- 主要文本为：“Islam fs louel” 4a lintoniral。\n- 这些词表面并无直接可辨识的英文单词，但可能为有意变形、讽刺，或用来绕开内容检测的拼写。\n- 将"Islam"与杂乱无章组合其余字母，似乎试图造成与穆斯林有关的含混、模糊但可能带有不良指向的语境。\n\n**3. 融合关系：**  \n- 少女的微笑形象与帽子内容（不明意义）本身是中性的，也带有一种日常幽默或玩笑气氛。\n- 但配以文本“Islam fs louel”及其后半截容易被感知为无意义或刻意拼写（比如“Islam fake/lol/lovel”等的混写），是否定，有可能是网络用语在尝试贬低或调侃与伊斯兰相关的话题，结合“A”与随后的无意义字串，有可能是模糊表达甚至是变体暗语。\n\n---\n\n### 二、是否包含歧视、暴力、血腥、误导性等不良内容？\n\n**1. 歧视与仇恨：**  \n- 图片文本提到“Islam”（伊斯兰），是具体的宗教群体名称；结合混乱拼写的后缀，常见于某些网络仇恨言论规避检测的手段。\n- 若“fs louel”是有意的phishing拼写（如fake/lol等谐音、双关等），可能表明对伊斯兰宗教的贬低或嘲笑。\n- 图像中女孩的微笑和帽子内容与文本缺乏直接关联，但此类构图用于互联网迷因时，常用“无辜形象+攻击性话语”的方式来降低攻击性的表面暴力感，却更隐蔽地达成讽刺或辱骂。\n\n**2. 暴力或血腥暗示：**  \n- 该图像视觉风格未见直接的暴力或血腥内容，但文本如果为变形侮辱词，则存在情感暴力成分。\n\n**3. 误导性或其他负面：**  \n- 文本混乱，也可能让误解为无意义，但在迷因语境下常为“眼熟即懂”的线索码，用于群体内部认同和排斥，用以暗示对某些群体的否定或嘲弄。\n\n---\n\n### 三、结合图像与文字，是否存在仇恨言论或有害暗示？\n\n**1. 图像与文字的相互作用：**  \n- 虽然图片本人展现微笑，帽子内容不明，但与带有歧视暗示的（变体）文字融合时，往往通过对比（如“无辜+攻击/贬损”）放大了人格矛盾与社交讽刺的效果。\n- 文字中的“Islam”直接指代伊斯兰，这样的具名在疑似贬低语境下，极易构成对宗教群体的歧视。\n- 网络文化中，“loul”“fs”等字母可能借音、变体绕开“hate speech”检测，并被相关群体解码出恶意含义。\n\n**2. 情感色彩整体效应：**  \n- 看似欢乐、无害的视觉风格掩盖了文本中潜藏的歧视与负向情感，对观看者尤其是相关群体有隐伤和冒犯作用。\n- 图像与文字结合，创造了一种“幽默外衣下的冷暴力”或“以讥讽为主的仇恨表现”，这正是现代网络仇恨迷因常用的策略。\n\n---\n\n## 结论\n\n**A. 综合来看，图像和文字结合后，这个迷因很可能传递出有关伊斯兰宗教的讽刺、贬损、甚至仇恨暗示。**  \n- 虽没有直白的暴力、恐吓、流血画面，但通过文本的拼写变体及刻意指向宗教，本质上具有歧视和伤害性，属于“隐性仇恨言论”。  \n- 图像和文字的融合掩盖了负面情绪，但对目标群体依然能造成心理伤害和社群伤害。\n\n**B. 若用于内容审核，应将其视为潜在仇恨迷因，建议加强重点关注，防止更大范围传播和引发群体冲突。**\n\n---\n\n**（如需从心理或社会影响继续深入分析，也可进一步提供）**', 'sentiment': ['暴力', '攻击', '血腥', '仇恨', '仇恨言论', '讽刺', '贬低'], 'keywords': array(['fs', 'islam', 'louel', '是有意的phishing拼写', '贬损'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################
#
# 正在分析: 39214.png
# 生成的描述： a woman eating a banana
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 推理时间: 17.52秒
# 消耗Token数量: 1462
# 推理费用: $0.0439
# 分析总结： {'description': '作为一位经验丰富的心理学家、社会学家，在分析Facebook Hateful Memes Detection任务时，针对您提供的图像与文字信息，做如下综合分析：\n\n---\n\n**一、图像和文字如何共同构建整体信息？**\n\n- **视觉内容**：图像展现的是“一位女性正在吃香蕉”，从视觉上这是一个普通的日常行为，没有明确的情绪指向，也未显示出明显的情感或态度。\n- **文字解读**：\n    - 文本内容：“whats the Dest thing. abo mt fal\n    \n    tnhemOMINUutesorsilence!”\n    - 文字似乎有拼写、语法错误，很难完整、准确地理解原意。"whats the Dest thing about mt fal" 可以推测是 "What\'s the best thing about my fall"，但也可能是 "What\'s the best thing about me, fall...". “tnhemOMINUutesorsilence!” 很难还原完整含义，可能是 "then OMNI minutes of silence!" 或 "ten minutes of silence!" 或其他变体。\n    - 整体语义模糊，不清楚其对女性、吃香蕉行为，还是其他内容进行陈述。\n\n- **图像-文本融合**：\n    - 图像本身中性，文字模糊。但在社交媒体语境下，女性吃香蕉有时会被用作暗示性、性别歧视甚至侮辱的梗。\n    - 文字没有直接侮辱、暴力词汇，但由于不够清晰，无法排除其特殊暗示的可能性。\n    - 两者结合后信息仍旧含混，没有直接的恶意表达。\n\n---\n\n**二、是否传递出歧视、暴力、血腥、误导性等不良内容？**\n\n- **歧视与仇恨**：\n    - 目前文字和图片结合没有清晰表达针对某一群体的歧视或仇恨。\n    - 但是，考虑到“女性吃香蕉”在网络文化中可能被恶意用作性暗示，在不同语境和目标受众中图片可能被曲解为带有性别歧视或者性化女性的隐喻。\n    - 文字“minutes of silence！”（如果是该意思）通常用于纪念或表示敬意，也可能用于讽刺，但并没有直接的歧视或恶意表达。\n\n- **暴力与血腥**：\n    - 并无视觉或文本上的暴力、血腥暗示。\n\n- **误导性内容**：\n    - 信息整体不够清晰和完整，不具备显著误导性，但不排除弱暗示、讽刺等不良用法。\n\n---\n\n**三、是否存在仇恨言论、暴力或任何有害的暗示？**\n\n- **仇恨言论**：\n    - 没有直接、明确的仇恨言论。\n    - 但需注意“女性吃香蕉”被用作互联网隐喻及嘲讽对象——因此，在某些受众和社交语境中，可能被读取为性别羞辱或性化（尤其如果文字部分本意是“最佳地方是沉默的XX分钟”，暗指女性不说话等贬低偏见）。\n    - 如果存在文本拼写错误，原文恶意被遮掩，需进一步核查真实语境。\n\n- **暴力/有害暗示**：\n    - 暴力内容缺失。\n    - 有害暗示（尤其是潜在性别歧视或性化女性）存在可能性，但并不明确。\n\n---\n\n**四、情感色彩与作用机制分析**\n\n- **中性或温和语气**：\n    - 文字未体现直接强烈的情感，但由于模糊性，易被不同群体解读为戏谑、讽刺或甚至刻薄。\n    - 图像本身无恶意，但与文字结合在特定文化语境下可能传递弱性暗示或性别刻板印象。\n- **解读多样性**：\n    - 这种“图文不明”的内容很容易被误读成恶意，与受众背景高度相关，需要结合传播语境进一步分析。\n\n---\n\n#### 总结：\n\n1. **图像和文字结合后未直接传递出仇恨、暴力、血腥或误导性内容，但潜在暗示需警惕。**\n2. **在特定网络语境下，‘女性吃香蕉’图像配合含糊不清的文字，可能被用作性化女性或性别歧视的隐喻。**\n3. **当前文本模糊难以识别恶意，但建议结合具体语境、原帖评论及传播环境进一步甄别。**\n4. **图像和文字的互动可能增强观看者的主观解读，有必要关注目标受众对该内容的实际反应。**\n\n---\n\n**建议：**\n- 对于自动化仇恨内容检测任务，应将此图像-文字对标记为“需进一步人工审核”，并结合历史使用语境、评论区反应等综合判定是否构成仇恨或有害内容。\n- 在社交网络环境下，特别注意隐蔽表达和模糊文本下的潜在暗示对不同群体的影响。\n\n---\n\n如需更深入分析，请补充上下文和真实原文，或提供其在社交媒体上的实际使用语境。', 'sentiment': ['暴力', '性别歧视', '血腥', '仇恨', '仇恨言论', '讽刺', '贬低'], 'keywords': array(['minutes', 'silence', 'thing', '女性吃香蕉', '暴力'], dtype=object), 'semantic_analysis': 1}
#
# ########################################################################################################################

# %%
! pip install jsonlines
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages (from jsonlines) (25.4.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0

# %% [markdown]
# ## BLIP-based Training Downstream Tasks (HMD)

# %%
import openai
import os
import requests
from PIL import Image
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration, BertTokenizer, BertForSequenceClassification
from sklearn.model_selection import train_test_split
import pytesseract  # 用于OCR（文字识别）
import time
import torch
from torch.utils.data import DataLoader, Dataset
from torch.optim import AdamW
from sklearn.metrics import accuracy_score
import jsonlines
from tqdm import tqdm  # For progress bar

# 设置API密钥和URL
API_SECRET_KEY = "sk-zk21884c49fc398427914f99fc30171ecb068f998dc6f05b"
BASE_URL = "https://api.zhizengzeng.com/v1/chat/completions"

# 加载BLIP模型和处理器
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 加载BERT模型（用于文本分类）
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)  # 二分类：仇恨或非仇恨

# 扩展的细粒度关键词列表（多模态信息捕捉的关键细节）
captions_keywords = [
    '暴力', '攻击', '恐怖主义', '战争', '杀戮', '残忍',
    '种族歧视', '性别歧视', '年龄歧视', '贫富差距', '身体歧视', '宗教歧视', 
    '同性恋歧视', '外貌歧视', '血腥', '凶杀', '残忍行为', '血腥场面',
    '谣言', '假新闻', '恶意炒作', '虚假信息', '误导性广告',
    '仇恨', '恶意攻击', '恶性竞争', '污蔑', '恶意散布',
    '不道德', '不正当手段', '欺诈', '贪婪', '非法活动', '敲诈', '诈骗',
    '仇恨言论', '仇恨犯罪', '排外', '性别仇恨', '宗教仇恨',
    '精神虐待', '心理操控', '精神暴力', '霸凌', '讽刺', '贬低',
    '毒品', '吸毒', '暴饮暴食', '酗酒', '赌博',
    '淫秽内容', '色情', '淫秽语言', '性骚扰', '侵犯隐私',
    '贫困', '贫困歧视', '社会不公', '政治迫害', '暴政',
    '极端主义', '极右翼', '极左翼', '民族主义', '恐怖主义意识形态'
]

# 加载图像并进行处理
def load_image(image_path):
    image = Image.open(image_path)
    return image

# 图像文字识别函数（OCR）
def extract_text_from_image(image_path):
    image = load_image(image_path)
    text = pytesseract.image_to_string(image)
    return text.strip()

# 使用BLIP生成图像描述
def describe_image_with_blip(image_path):
    image = load_image(image_path)
    inputs = processor(image, return_tensors="pt")
    out = blip_model.generate(**inputs)
    description = processor.decode(out[0], skip_special_tokens=True)
    return description

# 生成分析内容的Prompt
def generate_analysis_prompt(image_path, description):
    text_from_image = extract_text_from_image(image_path)
    prompt = (
        f"假如你是一位具有非常丰富经验的心理学家、社会学家，现在需要完成**Facebook Hateful Memes Detection**任务，"
        f"请综合分析以下图像内容与图像中的文字信息，特别关注图像和文字的融合信息，考虑到它们如何共同表达和加强潜在的情感和信息：\n"
        f"图像描述：{description}\n"
        f"图像中的文字：{text_from_image}\n"
        f"请结合图像的视觉内容和文字的语义信息，从以下几个维度进行分析：\n"
        f"- 图像和文字如何共同构建整体信息？\n"
        f"- 这张图像和文字结合后是否传递出歧视、暴力、血腥、误导性等不良内容？\n"
        f"- 结合图像与文字的信息，是否存在仇恨言论、暴力、或任何有害的暗示？\n"
        f"请特别关注图像和文字如何相互作用以及它们对情感色彩的共同影响。"
    )
    return prompt

# 进行情感分析，判断是否包含仇恨言论
def hateful_analysis(text):
    detected_keywords = []
    for keyword in captions_keywords:
        if keyword in text:
            detected_keywords.append(keyword)
    return detected_keywords if detected_keywords else ["not hateful"]

# 提取多个情感色彩关键词
def extract_keywords(text):
    vectorizer = TfidfVectorizer(stop_words='english', max_features=5)  # 提取最重要的前5个关键词
    tfidf_matrix = vectorizer.fit_transform([text])
    feature_names = np.array(vectorizer.get_feature_names_out())
    return feature_names  # 返回多个关键词

# 语义理解（BERT）: 使用BERT模型进行分析
def semantic_understanding(text):
    inputs = bert_tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    outputs = bert_model(**inputs)
    prediction = outputs.logits.argmax().item()  # 获取分类结果
    return 1 if prediction == 1 else 0  # 输出1代表包含仇恨，0代表没有

# 定义图像-文本数据集类
class MultimodalDataset(Dataset):
    def __init__(self, image_paths, texts, labels, processor, tokenizer):
        self.image_paths = image_paths
        self.texts = texts
        self.labels = labels
        self.processor = processor
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # 加载图像并生成描述
        image_path = self.image_paths[idx]
        image = Image.open(image_path)
        inputs = self.processor(image, return_tensors="pt")
        text = self.texts[idx]
        labels = self.labels[idx]
        
        # 文本编码
        encoding = self.tokenizer(text, truncation=True, padding='max_length', max_length=128, return_tensors="pt")

        return {
            'image': inputs.pixel_values.squeeze(),  # 图像
            'input_ids': encoding['input_ids'].squeeze(),  # 文本
            'attention_mask': encoding['attention_mask'].squeeze(),  # 文本mask
            'labels': torch.tensor(labels)  # 标签
        }

# 数据加载和训练过程
def run_training(train_data_file, num_images=None):
    # 读取训练数据（jsonl格式）
    image_paths = []
    texts = []
    labels = []

    with jsonlines.open(train_data_file) as reader:
        for obj in reader:
            # print(f'obj: {obj}')
            image_paths.append(f"/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/{obj['img']}")
            texts.append(obj['text'])
            labels.append(obj['label'])

    # 切分数据集
    train_image_paths, val_image_paths, train_texts, val_texts, train_labels, val_labels = train_test_split(image_paths, texts, labels, test_size=0.4)

    # 创建数据集
    train_dataset = MultimodalDataset(train_image_paths, train_texts, train_labels, processor, bert_tokenizer)
    val_dataset = MultimodalDataset(val_image_paths, val_texts, val_labels, processor, bert_tokenizer)

    train_dataloader = DataLoader(train_dataset, batch_size=2, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=2)

    # 准备模型和优化器
    model = torch.nn.ModuleList([blip_model, bert_model]).to(device)
    optimizer = AdamW(model.parameters(), lr=1e-4)

    # 训练模型
    train_model(train_dataloader, model, optimizer)

    # 评估模型（简化）
    accuracy = evaluate_model(val_dataloader, model)
    print(f"Validation Accuracy: {accuracy}")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
run_training('/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/all_data/train.jsonl', num_images=5)
# Out:
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 8405.42it/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 168
#     165     print(f"Validation Accuracy: {accuracy}")
#     167 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# --> 168 run_training('/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data/all_data/train.jsonl', num_images=5)
#
# Cell In[17], line 161, in run_training(train_data_file, num_images)
#     158 optimizer = AdamW(model.parameters(), lr=1e-4)
#     160 # 训练模型
# --> 161 train_model(train_dataloader, model, optimizer)
#     163 # 评估模型（简化）
#     164 accuracy = evaluate_model(val_dataloader, model)
#
# Cell In[9], line 70, in train_model(train_dataloader, model, optimizer, num_epochs)
#      67 labels = batch['labels'].to(device)
#      69 # 图像描述生成
# ---> 70 outputs = blip_model.generate(pixel_values=image_inputs)  # 生成图像描述
#      71 caption = processor.decode(outputs[0], skip_special_tokens=True)  # Decode generated caption
#      73 # 文本分类
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/transformers/models/blip/modeling_blip.py:1041, in BlipForConditionalGeneration.generate(self, pixel_values, input_ids, attention_mask, interpolate_pos_encoding, **generate_kwargs)
#    1008 r"""
#    1009 Overrides *generate* function to be able to use the model as a conditional generator
#    1010
#    (...)   1037 ```
#    1038 """
#    1040 batch_size = pixel_values.shape[0]
# -> 1041 vision_outputs = self.vision_model(
#    1042     pixel_values=pixel_values,
#    1043     interpolate_pos_encoding=interpolate_pos_encoding,
#    1044 )
#    1046 image_embeds = vision_outputs[0]
#    1048 image_attention_mask = torch.ones(image_embeds.size()[:-1], dtype=torch.long, device=image_embeds.device)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/transformers/models/blip/modeling_blip.py:587, in BlipVisionModel.forward(self, pixel_values, output_attentions, output_hidden_states, return_dict, interpolate_pos_encoding)
#     583     raise ValueError("You have to specify pixel_values")
#     585 hidden_states = self.embeddings(pixel_values, interpolate_pos_encoding=interpolate_pos_encoding)
# --> 587 encoder_outputs = self.encoder(
#     588     inputs_embeds=hidden_states,
#     589     output_attentions=output_attentions,
#     590     output_hidden_states=output_hidden_states,
#     591     return_dict=return_dict,
#     592 )
#     594 last_hidden_state = encoder_outputs[0]
#     595 last_hidden_state = self.post_layernorm(last_hidden_state)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/transformers/models/blip/modeling_blip.py:531, in BlipEncoder.forward(self, inputs_embeds, attention_mask, output_attentions, output_hidden_states, return_dict)
#     528 if output_hidden_states:
#     529     encoder_states = encoder_states + (hidden_states,)
# --> 531 layer_outputs = encoder_layer(
#     532     hidden_states,
#     533     attention_mask=attention_mask,
#     534     output_attentions=output_attentions,
#     535 )
#     537 hidden_states = layer_outputs[0]
#     539 if output_attentions:
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/transformers/models/blip/modeling_blip.py:415, in BlipEncoderLayer.forward(self, hidden_states, attention_mask, output_attentions)
#     412 residual = hidden_states
#     414 hidden_states = self.layer_norm1(hidden_states)
# --> 415 hidden_states, attn_weights = self.self_attn(
#     416     hidden_states=hidden_states,
#     417     head_mask=attention_mask,
#     418     output_attentions=output_attentions,
#     419 )
#     420 hidden_states = hidden_states + residual
#     421 residual = hidden_states
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/transformers/models/blip/modeling_blip.py:349, in BlipAttention.forward(self, hidden_states, head_mask, output_attentions)
#     346 attention_scores = attention_scores * self.scale
#     348 # Normalize the attention scores to probabilities.
# --> 349 attention_probs = nn.functional.softmax(attention_scores, dim=-1)
#     351 # This is actually dropping out entire tokens to attend to, which might
#     352 # seem a bit unusual, but is taken from the original Transformer paper.
#     353 attention_probs = self.dropout(attention_probs)
#
# File /opt/anaconda3/envs/mlenv/lib/python3.13/site-packages/torch/nn/functional.py:2137, in softmax(input, dim, _stacklevel, dtype)
#    2135     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    2136 if dtype is None:
# -> 2137     ret = input.softmax(dim)
#    2138 else:
#    2139     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# ---
