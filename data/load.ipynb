# %% [markdown]
# # Create Empty "data" File

# %%
import os

# 创建 'data' 文件夹（如果它还不存在）
# 记得修改路径
data_dir = "/Users/gidle/Desktop/Year3/NLP/Project/Hateful memes challenge/DATA"
if not os.path.exists(data_dir):
    os.makedirs(data_dir)
    print(f"'data' file created: {data_dir}")
else:
    print(f"'data' file existed: {data_dir}")
# Out:
# 'data' file existed: /Users/gidle/Desktop/Year3/NLP/Project/Hateful memes challenge/DATA

# %% [markdown]
# # DataLoad Kaggle [seen]

# %%
# import kagglehub

# # Specify your custom download path
# # /Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data
# # custom_path = "/path/to/your/custom/folder"
# custom_path = "/Users/suleynan_suir/Desktop/NLP_Package/Project/Hateful-Image-Project/data"

# # Download latest version of the dataset
# path = kagglehub.dataset_download("parthplc/facebook-hateful-meme-dataset", path=custom_path)

# print("Path to dataset files:", path)

#import kagglehub

# 设置自定义下载路径
# custom_path = "/Users/gidle/Desktop/Year3/NLP/Project/Hateful memes challenge"

# 下载最新版本的数据集
# path = kagglehub.dataset_download("parthplc/facebook-hateful-meme-dataset", path=custom_path)

# print("Dataset Path:", path)

# %% [markdown]
# ### 下面记得改your custom download path

# %%
# !kaggle datasets download -d parthplc/facebook-hateful-meme-dataset -p "/Users/gidle/Desktop/Year3/NLP/Project/Hateful memes challenge" --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/parthplc/facebook-hateful-meme-dataset
# License(s): unknown
# Downloading facebook-hateful-meme-dataset.zip to /Users/gidle/Desktop/Year3/NLP/Project/Hateful memes challenge
#   0%|          | 0.00/3.35G [00:00<?, ?B/s]
#   2%|▏         | 52.0M/3.35G [00:00<00:06, 535MB/s]
#   3%|▎         | 112M/3.35G [00:00<00:05, 588MB/s]
#   5%|▍         | 169M/3.35G [00:00<00:05, 591MB/s]
#   7%|▋         | 226M/3.35G [00:00<00:05, 572MB/s]
#   8%|▊         | 285M/3.35G [00:00<00:05, 586MB/s]
#  10%|▉         | 341M/3.35G [00:00<00:05, 573MB/s]
#  12%|█▏        | 396M/3.35G [00:00<00:05, 544MB/s]
#  13%|█▎        | 449M/3.35G [00:00<00:05, 542MB/s]
#  15%|█▍        | 501M/3.35G [00:00<00:05, 518MB/s]
#  16%|█▋        | 559M/3.35G [00:01<00:05, 542MB/s]
#  18%|█▊        | 611M/3.35G [00:01<00:08, 335MB/s]
#  19%|█▉        | 668M/3.35G [00:01<00:07, 388MB/s]
#  21%|██        | 725M/3.35G [00:01<00:06, 434MB/s]
#  23%|██▎       | 782M/3.35G [00:01<00:05, 473MB/s]
#  24%|██▍       | 834M/3.35G [00:01<00:05, 489MB/s]
#  26%|██▌       | 887M/3.35G [00:01<00:05, 506MB/s]
#  27%|██▋       | 939M/3.35G [00:02<00:06, 432MB/s]
#  29%|██▊       | 985M/3.35G [00:02<00:06, 384MB/s]
#  30%|███       | 1.01G/3.35G [00:02<00:05, 421MB/s]
#  31%|███▏      | 1.06G/3.35G [00:02<00:07, 331MB/s]
#  33%|███▎      | 1.10G/3.35G [00:02<00:06, 372MB/s]
#  35%|███▍      | 1.16G/3.35G [00:02<00:05, 425MB/s]
#  94%|█████████▍| 3.16G/3.35G [00:08<00:00, 387MB/s]
#  96%|█████████▌| 3.20G/3.35G [00:09<00:01, 105MB/s]
#  97%|█████████▋| 3.26G/3.35G [00:09<00:00, 144MB/s]
#  99%|█████████▉| 3.32G/3.35G [00:09<00:00, 193MB/s]
# 100%|██████████| 3.35G/3.35G [00:09<00:00, 362MB/s]
# Dataset URL: https://www.kaggle.com/datasets/parthplc/facebook-hateful-meme-dataset
# License(s): unknown
# Downloading facebook-hateful-meme-dataset.zip to /Users/gidle/Desktop/Year3/NLP/Project/Hateful memes challenge
#   0%|          | 0.00/3.35G [00:00<?, ?B/s]
#   1%|          | 30.0M/3.35G [00:00<00:11, 306MB/s]
#   2%|▏         | 60.0M/3.35G [00:00<00:11, 298MB/s]
#   3%|▎         | 89.0M/3.35G [00:00<00:11, 296MB/s]
#   3%|▎         | 118M/3.35G [00:00<00:12, 286MB/s]
#   4%|▍         | 148M/3.35G [00:00<00:11, 294MB/s]
#   5%|▌         | 177M/3.35G [00:00<00:12, 280MB/s]
#   6%|▌         | 205M/3.35G [00:00<00:12, 280MB/s]
#   7%|▋         | 232M/3.35G [00:00<00:12, 271MB/s]
#   8%|▊         | 258M/3.35G [00:00<00:12, 265MB/s]
#   8%|▊         | 285M/3.35G [00:01<00:12, 270MB/s]
#   9%|▉         | 311M/3.35G [00:01<00:12, 270MB/s]
#  10%|▉         | 337M/3.35G [00:01<00:12, 270MB/s]
#  11%|█         | 367M/3.35G [00:01<00:11, 280MB/s]
#  11%|█▏        | 394M/3.35G [00:01<00:11, 281MB/s]
#  12%|█▏        | 424M/3.35G [00:01<00:10, 290MB/s]
#  13%|█▎        | 454M/3.35G [00:01<00:10, 296MB/s]
#  14%|█▍        | 483M/3.35G [00:01<00:10, 290MB/s]
#  15%|█▍        | 511M/3.35G [00:01<00:10, 289MB/s]
#  16%|█▌        | 539M/3.35G [00:02<00:13, 233MB/s]
#  16%|█▋        | 565M/3.35G [00:02<00:12, 241MB/s]
#  17%|█▋        | 591M/3.35G [00:02<00:11, 249MB/s]
#  18%|█▊        | 616M/3.35G [00:02<00:11, 250MB/s]
#  19%|█▉        | 644M/3.35G [00:02<00:11, 260MB/s]
#  20%|█▉        | 673M/3.35G [00:02<00:10, 271MB/s]
#  20%|██        | 700M/3.35G [00:02<00:10, 261MB/s]
#  21%|██        | 726M/3.35G [00:02<00:10, 260MB/s]
#  22%|██▏       | 752M/3.35G [00:03<00:15, 186MB/s]
#  23%|██▎       | 774M/3.35G [00:03<00:14, 194MB/s]
#  23%|██▎       | 800M/3.35G [00:03<00:13, 212MB/s]
#  24%|██▍       | 828M/3.35G [00:03<00:11, 233MB/s]
#  25%|██▍       | 853M/3.35G [00:03<00:11, 240MB/s]
#  26%|██▌       | 885M/3.35G [00:03<00:10, 265MB/s]
#  27%|██▋       | 912M/3.35G [00:03<00:12, 207MB/s]
#  27%|██▋       | 939M/3.35G [00:03<00:11, 223MB/s]
#  28%|██▊       | 967M/3.35G [00:03<00:10, 239MB/s]
#  29%|██▉       | 992M/3.35G [00:04<00:10, 245MB/s]
#  30%|██▉       | 0.99G/3.35G [00:04<00:11, 220MB/s]
#  66%|██████▌   | 2.21G/3.35G [00:09<00:05, 245MB/s]
#  67%|██████▋   | 2.24G/3.35G [00:09<00:04, 258MB/s]
#  67%|██████▋   | 2.26G/3.35G [00:10<00:06, 193MB/s]
#  68%|██████▊   | 2.29G/3.35G [00:10<00:05, 211MB/s]
#  69%|██████▉   | 2.31G/3.35G [00:10<00:05, 223MB/s]
#  70%|██████▉   | 2.33G/3.35G [00:10<00:04, 232MB/s]
#  70%|███████   | 2.36G/3.35G [00:10<00:04, 240MB/s]
#  71%|███████   | 2.38G/3.35G [00:10<00:05, 184MB/s]
#  72%|███████▏  | 2.41G/3.35G [00:10<00:04, 203MB/s]
#  73%|███████▎  | 2.44G/3.35G [00:10<00:04, 223MB/s]
#  73%|███████▎  | 2.46G/3.35G [00:10<00:04, 236MB/s]
#  74%|███████▍  | 2.49G/3.35G [00:11<00:03, 251MB/s]
#  75%|███████▍  | 2.51G/3.35G [00:11<00:04, 201MB/s]
#  76%|███████▌  | 2.54G/3.35G [00:11<00:03, 227MB/s]
#  77%|███████▋  | 2.57G/3.35G [00:11<00:03, 245MB/s]
#  78%|███████▊  | 2.60G/3.35G [00:11<00:03, 258MB/s]
#  78%|███████▊  | 2.63G/3.35G [00:12<00:06, 130MB/s]
#  79%|███████▉  | 2.65G/3.35G [00:13<00:13, 54.9MB/s]
#  80%|███████▉  | 2.68G/3.35G [00:13<00:09, 79.9MB/s]
#  81%|████████  | 2.71G/3.35G [00:13<00:06, 109MB/s]
#  82%|████████▏ | 2.75G/3.35G [00:13<00:04, 141MB/s]
#  83%|████████▎ | 2.78G/3.35G [00:13<00:03, 177MB/s]
#  84%|████████▍ | 2.82G/3.35G [00:13<00:02, 208MB/s]
#  85%|████████▌ | 2.85G/3.35G [00:13<00:02, 242MB/s]
#  86%|████████▌ | 2.89G/3.35G [00:13<00:01, 272MB/s]
#  87%|████████▋ | 2.92G/3.35G [00:13<00:01, 295MB/s]
#  88%|████████▊ | 2.95G/3.35G [00:14<00:01, 309MB/s]
#  89%|████████▉ | 2.99G/3.35G [00:14<00:01, 318MB/s]
#  90%|█████████ | 3.02G/3.35G [00:14<00:01, 317MB/s]
#  91%|█████████ | 3.05G/3.35G [00:14<00:01, 313MB/s]
#  92%|█████████▏| 3.08G/3.35G [00:14<00:01, 266MB/s]
#  93%|█████████▎| 3.12G/3.35G [00:14<00:00, 287MB/s]
#  94%|█████████▍| 3.15G/3.35G [00:14<00:00, 303MB/s]
#  95%|█████████▍| 3.18G/3.35G [00:14<00:00, 310MB/s]
#  96%|█████████▌| 3.21G/3.35G [00:14<00:00, 317MB/s]
#  97%|█████████▋| 3.25G/3.35G [00:15<00:00, 316MB/s]
#  98%|█████████▊| 3.28G/3.35G [00:15<00:00, 319MB/s]
#  99%|█████████▊| 3.31G/3.35G [00:15<00:00, 327MB/s]
# 100%|█████████▉| 3.34G/3.35G [00:15<00:00, 324MB/s]
# 100%|██████████| 3.35G/3.35G [00:15<00:00, 233MB/s]

# %% [markdown]
# # DataLoad Fine_grained File
#
# source link: https://github.com/facebookresearch/fine_grained_hateful_memes

# %%
! pip install requests
! pip install gitpython
# Out:
# Requirement already satisfied: requests in d:\programdata\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\programdata\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\programdata\anaconda3\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programdata\anaconda3\lib\site-packages (from requests) (2022.9.14)
# Requirement already satisfied: gitpython in d:\programdata\anaconda3\lib\site-packages (3.1.45)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\programdata\anaconda3\lib\site-packages (from gitpython) (4.0.12)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in d:\programdata\anaconda3\lib\site-packages (from gitpython) (4.15.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.2)

# %%
# import os
# from git import Repo

# # Step 1: Clone the repository
# # repo_url = "https://github.com/facebookresearch/fine_grained_hateful_memes.git"
# repo_url = "https://github.com/facebookresearch/fine_grained_hateful_memes.git"
# repo_dir = "fine_grained_hateful_memes"  # Temporary directory to clone the repo

# if not os.path.exists(repo_dir):
#     Repo.clone_from(repo_url, repo_dir)

# # Step 2: Move and rename the annotations folder
# source_folder = os.path.join(repo_dir, "data", "annotations")
# destination_folder = os.path.join("data", "hateful_memes_finegrained")  # Directly in the existing 'data' folder

# if os.path.exists(source_folder):
#     # Rename and move the folder to the existing 'data' folder
#     os.rename(source_folder, destination_folder)
#     print(f"Successfully moved and renamed the folder to: {destination_folder}")
# else:
#     # print("仓库中没有找到 'annotations' 文件夹（重命名为 hateful_memes_finegrained）。")
#     "The 'annotations' folder (renamed: hateful_memes_finegrained) does not exist in the repository."

# %%
import os
from git import Repo

# 第一步：克隆仓库
repo_url = "https://github.com/facebookresearch/fine_grained_hateful_memes.git"
repo_dir = "fine_grained_hateful_memes"  # 临时目录用于克隆仓库

if not os.path.exists(repo_dir):
    Repo.clone_from(repo_url, repo_dir)

# 第二步：移动并重命名 'annotations' 文件夹
source_folder = os.path.join(repo_dir, "data", "annotations")
destination_folder = os.path.join(data_dir, "hateful_memes_finegrained")  # 直接放入已存在的 'data' 文件夹

if os.path.exists(source_folder):
    # 将文件夹重命名并移动到 'data' 文件夹
    os.rename(source_folder, destination_folder)
    print(f"The folder was successfully moved and renamed: {destination_folder}")
else:
    print("Not found in the repo 'annotations', File folder (renamed: hateful_memes_finegrained)")
# Out:
# The folder was successfully moved and renamed: /Users/gidle/Desktop/Year3/NLP/Project/Hateful memes challenge/DATA\hateful_memes_finegrained

# %%
# import os
# import requests
# from git import Repo

# # Step 1: Clone the repository
# repo_url = "https://github.com/facebookresearch/fine_grained_hateful_memes.git"
# repo_dir = "fine_grained_hateful_memes"  # Temporary directory to clone the repo

# if not os.path.exists(repo_dir):
#     Repo.clone_from(repo_url, repo_dir)

# # Step 2: Move and rename the annotations folder
# source_folder = os.path.join(repo_dir, "data", "annotations")
# destination_folder = os.path.join("data", "hateful_memes_finegrained")

# if os.path.exists(source_folder):
#     # Ensure the 'data' directory exists in your current working directory
#     if not os.path.exists("data"):
#         os.makedirs("data")
    
#     # Rename and move the folder
#     os.rename(source_folder, destination_folder)
#     print(f"Successfully moved and renamed the folder to: {destination_folder}")
# else:
#     print("The 'annotations' folder (renamed: hateful_memes_finegrained) does not exist in the repository.")
# Out:
# Successfully moved and renamed the folder to: data\hateful_memes_finegrained
